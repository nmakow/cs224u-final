# %% [markdown]
# # Final Experiments

# %%
# 0. Some initial set-up.
from collections import Counter
import numpy as np
import os
import pandas as pd
import random
from tf_rnn_classifier import TfRNNClassifier
from collections import defaultdict, Counter
from sklearn.tree import DecisionTreeClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import cross_val_score
from scipy.sparse import hstack
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_fscore_support, classification_report, roc_auc_score
import tensorflow as tf
import sst
from utils import evaluate, build_rnn_dataset
import utils
# Out:
# /home/nmakow/anaconda3/envs/nlu/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
vsmdata_home = 'vsmdata'

glove_home = os.path.join(vsmdata_home, 'glove.6B')

data_dir = "./data/"

# %%
train = pd.read_csv(data_dir + "train.csv").fillna(' ')
test = pd.read_csv(data_dir + "test.csv").fillna(' ')
test_labels = pd.read_csv(data_dir + "test_labels.csv")

# %% [markdown]
# ## Dataset Set-up

# %%
X_rnn, Y_rnn = build_rnn_dataset(train, 0.9)

# %%
X_test, Y_test = build_rnn_dataset(test, 1)
X_test, Y_test = X_test['train'], Y_test['train']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7bea8c648797> in <module>()
# ----> 1 X_test, Y_test = build_rnn_dataset(test, 1)
#       2 X_test, Y_test = X_test['train'], Y_test['train']
#
# NameError: name 'build_rnn_dataset' is not defined

# %% [markdown]
# ## Baseline Features

# %%
label_cols = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
COMMENT = 'comment_text'
train_examples = train[COMMENT]
train_labels = train[label_cols]

# %%
train_text = [" ".join(ex) for ex in X_rnn['train']]
dev_text = [" ".join(ex) for ex in X_rnn['dev']]
all_text = train_text + dev_text
print(len(train_text), len(dev_text), len(all_text))
# Out:
# 143613 15958 159571

# %%
all_text = [" ".join(ex) for ex in X_rnn]

# %%
# may take several minutes...
word_vectorizer = TfidfVectorizer(
    sublinear_tf=True,
    strip_accents='unicode',
    analyzer='word',
    token_pattern=r'\w{1,}',
    stop_words='english',
    ngram_range=(1, 1),
    max_features=10000)
word_vectorizer.fit(all_text)
train_word_features = word_vectorizer.transform(train_text)
dev_word_features = word_vectorizer.transform(dev_text)

# %%
train_features = hstack([train_word_features])
dev_features = hstack([dev_word_features])

# %% [markdown]
# ## Glove

# %%
glove_lookup = utils.glove2dict(
    os.path.join(vsmdata_home, 'glove.6B.100d.txt'))

# %%
full_train_vocab = sst.get_vocab(X_rnn['train'])

# %%
glove_vocab = sorted(set(glove_lookup) & set(full_train_vocab))
print("Embedding matrix contains %d words." % len(glove_vocab))
# Out:
# Embedding matrix contains 55422 words.

# %%
glove_embedding = np.array([glove_lookup[w] for w in glove_vocab])

# %%
glove_vocab.append("$UNK")
glove_embedding = np.vstack(
    (glove_embedding, utils.randvec(glove_embedding.shape[1])))

# %%
full_glove_vocab = sorted(set(sst.get_vocab(X_rnn['train'])))
print("Embedding matrix contains %d words." % len(full_glove_vocab))
# Out:
# Embedding matrix contains 494751 words.

# %%
full_glove_embedding = np.array([
    glove_lookup[w] 
    if w in glove_lookup else utils.randvec(len(glove_lookup["hello"])) 
    for w in full_glove_vocab
])

# %%
full_glove_vocab.append("$UNK")
full_glove_embedding = np.vstack(
    (full_glove_embedding, utils.randvec(full_glove_embedding.shape[1])))

# %% [markdown]
# # Binary ALL

# %%
Y_rnn_binary = np.max(Y_rnn['train'], axis=1).reshape((-1, 1))
Y_rnn_binary_dev = np.max(Y_rnn['dev'], axis=1).reshape((-1, 1))
print(Y_rnn_binary.shape, Y_rnn_binary_dev.shape)
# Out:
# (143613, 1) (15958, 1)

# %% [markdown]
# ## 1. Baseline

# %%
classifier = LogisticRegression(C=0.1, solver='sag')
classifier.fit(train_word_features, Y_rnn_binary)
# Out:
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='sag', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
preds = classifier.predict_proba(train_features)[:, 1]
preds = np.expand_dims(preds, 1)

# %%
preds
# Out:
# array([[0.10612625],
#        [0.10612625],
#        [0.0945392 ],
#        ...,
#        [0.10612625],
#        [0.10612625],
#        [0.11740118]])

# %%
evaluate(Y_rnn_binary, preds)
# Out:
# p, r, f1: 0.0000, 0.0000, 0.0000
#
# average F1 score: 0.000000

# %% [markdown]
# ## 2. Deep

# %%
deep1 = TfRNNClassifier(
    full_glove_vocab,
    embedding=full_glove_embedding,
    embed_dim=100,
    hidden_dim=50,
    max_length=100,
    hidden_activation=tf.nn.tanh,
    cell_class=tf.nn.rnn_cell.LSTMCell, # LSTM
    train_embedding=True,
    max_iter=3,
    word_length=12,
    bidir_rnn=True, # Bidirectional RNN!
    dropout=0.2,
    eta=0.01,
    eval_every=1,
    experiment_name="BINARY_ALL_deep")

# %%
deep1.fit(X_rnn['train'][:], 
          Y_rnn_binary[:], 
          X_dev=X_rnn['dev'],
          y_dev=Y_rnn_binary_dev)
# Out:
# ./logs/BINARY_ALL_deep
# epoch 1, iter 1, loss 0.70816, batch_time 0.632
# epoch 1, iter 2, loss 0.34461, batch_time 0.586
# epoch 1, iter 3, loss 0.33011, batch_time 0.625
# epoch 1, iter 4, loss 0.30604, batch_time 0.617
# epoch 1, iter 5, loss 0.34285, batch_time 0.624
# epoch 1, iter 6, loss 0.31578, batch_time 0.577
# epoch 1, iter 7, loss 0.31118, batch_time 0.599
# epoch 1, iter 8, loss 0.31245, batch_time 0.672
# epoch 1, iter 9, loss 0.28501, batch_time 0.598
# epoch 1, iter 10, loss 0.31354, batch_time 0.661
# epoch 1, iter 11, loss 0.28506, batch_time 0.574
# epoch 1, iter 12, loss 0.26809, batch_time 0.583
# epoch 1, iter 13, loss 0.27459, batch_time 0.560
# epoch 1, iter 14, loss 0.27408, batch_time 0.562
# epoch 1, iter 15, loss 0.31646, batch_time 0.567
# epoch 1, iter 16, loss 0.27334, batch_time 0.583
# epoch 1, iter 17, loss 0.27119, batch_time 0.587
# epoch 1, iter 18, loss 0.25123, batch_time 0.590
# epoch 1, iter 19, loss 0.28185, batch_time 0.578
# epoch 1, iter 20, loss 0.25312, batch_time 0.562
# epoch 1, iter 21, loss 0.25196, batch_time 0.582
# epoch 1, iter 22, loss 0.24083, batch_time 0.588
# epoch 1, iter 23, loss 0.25905, batch_time 0.573
# epoch 1, iter 24, loss 0.25099, batch_time 0.578
# epoch 1, iter 25, loss 0.24358, batch_time 0.572
# epoch 1, iter 26, loss 0.22193, batch_time 0.623
# epoch 1, iter 27, loss 0.26823, batch_time 0.594
# epoch 1, iter 28, loss 0.24620, batch_time 0.599
# epoch 1, iter 29, loss 0.30213, batch_time 0.597
# epoch 1, iter 30, loss 0.25906, batch_time 0.589
# epoch 1, iter 31, loss 0.23705, batch_time 0.598
# epoch 1, iter 32, loss 0.24260, batch_time 0.591
# epoch 1, iter 33, loss 0.21336, batch_time 0.568
# epoch 1, iter 34, loss 0.25250, batch_time 0.586
# epoch 1, iter 35, loss 0.19670, batch_time 0.647
# epoch 1, iter 36, loss 0.24759, batch_time 0.657
# epoch 1, iter 37, loss 0.23282, batch_time 0.585
# epoch 1, iter 38, loss 0.24389, batch_time 0.574
# epoch 1, iter 39, loss 0.21125, batch_time 0.583
# epoch 1, iter 40, loss 0.25828, batch_time 0.590
# epoch 1, iter 41, loss 0.23819, batch_time 0.592
# epoch 1, iter 42, loss 0.23241, batch_time 0.586
# epoch 1, iter 43, loss 0.19069, batch_time 0.691
# epoch 1, iter 44, loss 0.21137, batch_time 0.647
# epoch 1, iter 45, loss 0.20607, batch_time 0.654
# epoch 1, iter 46, loss 0.22454, batch_time 0.589
# epoch 1, iter 47, loss 0.21188, batch_time 0.596
# epoch 1, iter 48, loss 0.20559, batch_time 0.592
# epoch 1, iter 49, loss 0.21625, batch_time 0.594
# epoch 1, iter 50, loss 0.21783, batch_time 0.598
# epoch 1, iter 51, loss 0.20219, batch_time 0.608
# epoch 1, iter 52, loss 0.21358, batch_time 0.662
# epoch 1, iter 53, loss 0.17376, batch_time 0.652
# epoch 1, iter 54, loss 0.20676, batch_time 0.669
# epoch 1, iter 55, loss 0.20630, batch_time 0.632
# epoch 1, iter 56, loss 0.21446, batch_time 0.646
# epoch 1, iter 57, loss 0.21165, batch_time 0.602
# epoch 1, iter 58, loss 0.17292, batch_time 0.588
# epoch 1, iter 59, loss 0.17594, batch_time 0.593
# epoch 1, iter 60, loss 0.18295, batch_time 0.587
# epoch 1, iter 61, loss 0.18318, batch_time 0.587
# epoch 1, iter 62, loss 0.17675, batch_time 0.604
# epoch 1, iter 63, loss 0.21318, batch_time 0.588
# epoch 1, iter 64, loss 0.19977, batch_time 0.583
# epoch 1, iter 65, loss 0.20261, batch_time 0.595
# epoch 1, iter 66, loss 0.18572, batch_time 0.592
# epoch 1, iter 67, loss 0.16305, batch_time 0.582
# epoch 1, iter 68, loss 0.19607, batch_time 0.682
# epoch 1, iter 69, loss 0.19087, batch_time 0.579
# epoch 1, iter 70, loss 0.16198, batch_time 0.591
# epoch 1, iter 71, loss 0.14019, batch_time 0.655
# epoch 1, iter 72, loss 0.21954, batch_time 0.664
# epoch 1, iter 73, loss 0.16063, batch_time 0.589
# epoch 1, iter 74, loss 0.21912, batch_time 0.586
# epoch 1, iter 75, loss 0.19969, batch_time 0.591
# epoch 1, iter 76, loss 0.14693, batch_time 0.677
# epoch 1, iter 77, loss 0.16830, batch_time 0.668
# epoch 1, iter 78, loss 0.18081, batch_time 0.609
# epoch 1, iter 79, loss 0.19798, batch_time 0.608
# epoch 1, iter 80, loss 0.17842, batch_time 0.588
# epoch 1, iter 81, loss 0.15507, batch_time 0.669
# epoch 1, iter 82, loss 0.14190, batch_time 0.655
# epoch 1, iter 83, loss 0.16408, batch_time 0.639
# epoch 1, iter 84, loss 0.16223, batch_time 0.592
# epoch 1, iter 85, loss 0.21312, batch_time 0.590
# epoch 1, iter 86, loss 0.16578, batch_time 0.652
# epoch 1, iter 87, loss 0.19678, batch_time 0.643
# epoch 1, iter 88, loss 0.13322, batch_time 0.643
# epoch 1, iter 89, loss 0.19399, batch_time 0.606
# epoch 1, iter 90, loss 0.15302, batch_time 0.668
# epoch 1, iter 91, loss 0.17284, batch_time 0.647
# epoch 1, iter 92, loss 0.17333, batch_time 0.601
# epoch 1, iter 93, loss 0.15350, batch_time 0.661
# epoch 1, iter 94, loss 0.18089, batch_time 0.655
# epoch 1, iter 95, loss 0.14865, batch_time 0.688
# epoch 1, iter 96, loss 0.16551, batch_time 0.643
# epoch 1, iter 97, loss 0.14693, batch_time 0.610
# epoch 1, iter 98, loss 0.18314, batch_time 0.591
# epoch 1, iter 99, loss 0.15903, batch_time 0.649
# epoch 1, iter 100, loss 0.15697, batch_time 0.636
# epoch 1, iter 101, loss 0.14691, batch_time 0.577
# epoch 1, iter 102, loss 0.12300, batch_time 0.603
# epoch 1, iter 103, loss 0.19268, batch_time 0.653
# epoch 1, iter 104, loss 0.15173, batch_time 0.656
# epoch 1, iter 105, loss 0.14392, batch_time 0.651
# epoch 1, iter 106, loss 0.16525, batch_time 0.645
# epoch 1, iter 107, loss 0.15140, batch_time 0.606
# epoch 1, iter 108, loss 0.15335, batch_time 0.610
# epoch 1, iter 109, loss 0.15166, batch_time 0.658
# epoch 1, iter 110, loss 0.15286, batch_time 0.631
# epoch 1, iter 111, loss 0.14191, batch_time 0.648
# epoch 1, iter 112, loss 0.15593, batch_time 0.643
# epoch 1, iter 113, loss 0.15348, batch_time 0.657
# epoch 1, iter 114, loss 0.15449, batch_time 0.660
# epoch 1, iter 115, loss 0.15680, batch_time 0.648
# epoch 1, iter 116, loss 0.14985, batch_time 0.648
# epoch 1, iter 117, loss 0.18890, batch_time 0.646
# epoch 1, iter 118, loss 0.15703, batch_time 0.659
# epoch 1, iter 119, loss 0.13064, batch_time 0.610
# epoch 1, iter 120, loss 0.13147, batch_time 0.646
# epoch 1, iter 121, loss 0.15100, batch_time 0.648
# epoch 1, iter 122, loss 0.15812, batch_time 0.588
# epoch 1, iter 123, loss 0.17976, batch_time 0.593
# epoch 1, iter 124, loss 0.15021, batch_time 0.601
# epoch 1, iter 125, loss 0.15558, batch_time 0.666
# epoch 1, iter 126, loss 0.13994, batch_time 0.659
# epoch 1, iter 127, loss 0.16101, batch_time 0.647
# epoch 1, iter 128, loss 0.13868, batch_time 0.658
# epoch 1, iter 129, loss 0.12827, batch_time 0.646
# epoch 1, iter 130, loss 0.12825, batch_time 0.664
# epoch 1, iter 131, loss 0.12679, batch_time 0.628
# epoch 1, iter 132, loss 0.15115, batch_time 0.599
# epoch 1, iter 133, loss 0.15088, batch_time 0.583
# epoch 1, iter 134, loss 0.15331, batch_time 0.642
# epoch 1, iter 135, loss 0.16348, batch_time 0.639
# epoch 1, iter 136, loss 0.15352, batch_time 0.631
# epoch 1, iter 137, loss 0.14769, batch_time 0.611
# epoch 1, iter 138, loss 0.19353, batch_time 0.592
# epoch 1, iter 139, loss 0.13149, batch_time 0.649
# epoch 1, iter 140, loss 0.16512, batch_time 0.637
# Train Loss:  28.399861082434654
# Dev Loss:  2.4871413558721542
#
# epoch 2, iter 141, loss 0.12683, batch_time 0.632
# epoch 2, iter 142, loss 0.12021, batch_time 0.725
# epoch 2, iter 143, loss 0.11771, batch_time 0.646
# epoch 2, iter 144, loss 0.15469, batch_time 0.646
# epoch 2, iter 145, loss 0.10072, batch_time 0.620
# epoch 2, iter 146, loss 0.11201, batch_time 0.683
# epoch 2, iter 147, loss 0.11776, batch_time 0.637
# epoch 2, iter 148, loss 0.10888, batch_time 0.639
# epoch 2, iter 149, loss 0.09333, batch_time 0.647
# epoch 2, iter 150, loss 0.12438, batch_time 0.635
# epoch 2, iter 151, loss 0.11365, batch_time 0.643
# epoch 2, iter 152, loss 0.09355, batch_time 0.597
# epoch 2, iter 153, loss 0.10132, batch_time 0.589
# epoch 2, iter 154, loss 0.13741, batch_time 0.598
# epoch 2, iter 155, loss 0.12545, batch_time 0.589
# epoch 2, iter 156, loss 0.10911, batch_time 0.653
# epoch 2, iter 157, loss 0.10390, batch_time 0.641
# epoch 2, iter 158, loss 0.12876, batch_time 0.595
# epoch 2, iter 159, loss 0.11108, batch_time 0.590
# epoch 2, iter 160, loss 0.11232, batch_time 0.603
# epoch 2, iter 161, loss 0.10490, batch_time 0.595
# epoch 2, iter 162, loss 0.10732, batch_time 0.672
# epoch 2, iter 163, loss 0.09434, batch_time 0.660
# epoch 2, iter 164, loss 0.09341, batch_time 0.647
# epoch 2, iter 165, loss 0.10256, batch_time 0.642
# epoch 2, iter 166, loss 0.11190, batch_time 0.662
# epoch 2, iter 167, loss 0.10880, batch_time 0.633
# epoch 2, iter 168, loss 0.14018, batch_time 0.638
# epoch 2, iter 169, loss 0.10264, batch_time 0.580
# epoch 2, iter 170, loss 0.11059, batch_time 0.582
# epoch 2, iter 171, loss 0.12230, batch_time 0.607
# epoch 2, iter 172, loss 0.12169, batch_time 0.653
# epoch 2, iter 173, loss 0.11703, batch_time 0.647
# epoch 2, iter 174, loss 0.09927, batch_time 0.590
# epoch 2, iter 175, loss 0.11001, batch_time 0.662
# epoch 2, iter 176, loss 0.10315, batch_time 0.590
# epoch 2, iter 177, loss 0.13853, batch_time 0.597
# epoch 2, iter 178, loss 0.10734, batch_time 0.585
# epoch 2, iter 179, loss 0.13717, batch_time 0.605
# epoch 2, iter 180, loss 0.10436, batch_time 0.599
# epoch 2, iter 181, loss 0.10636, batch_time 0.581
# epoch 2, iter 182, loss 0.11975, batch_time 0.587
# epoch 2, iter 183, loss 0.11283, batch_time 0.668
# epoch 2, iter 184, loss 0.10715, batch_time 0.584
# epoch 2, iter 185, loss 0.11744, batch_time 0.585
# epoch 2, iter 186, loss 0.10251, batch_time 0.581
# epoch 2, iter 187, loss 0.12309, batch_time 0.655
# epoch 2, iter 188, loss 0.10085, batch_time 0.650
# epoch 2, iter 189, loss 0.11668, batch_time 0.600
# epoch 2, iter 190, loss 0.10658, batch_time 0.594
# epoch 2, iter 191, loss 0.11004, batch_time 0.583
# epoch 2, iter 192, loss 0.12043, batch_time 0.621
# epoch 2, iter 193, loss 0.09224, batch_time 0.683
# epoch 2, iter 194, loss 0.11388, batch_time 0.613
# epoch 2, iter 195, loss 0.08628, batch_time 0.602
# epoch 2, iter 196, loss 0.09161, batch_time 0.689
# epoch 2, iter 197, loss 0.08883, batch_time 0.693
# epoch 2, iter 198, loss 0.08464, batch_time 0.668
# epoch 2, iter 199, loss 0.11299, batch_time 0.650
# epoch 2, iter 200, loss 0.10227, batch_time 0.649
# epoch 2, iter 201, loss 0.09570, batch_time 0.607
# epoch 2, iter 202, loss 0.10761, batch_time 0.589
# epoch 2, iter 203, loss 0.11398, batch_time 0.595
# epoch 2, iter 204, loss 0.10626, batch_time 0.598
# epoch 2, iter 205, loss 0.11693, batch_time 0.594
# epoch 2, iter 206, loss 0.11385, batch_time 0.604
# epoch 2, iter 207, loss 0.08876, batch_time 0.611
# epoch 2, iter 208, loss 0.09208, batch_time 0.602
# epoch 2, iter 209, loss 0.10225, batch_time 0.600
# epoch 2, iter 210, loss 0.09798, batch_time 0.586
# epoch 2, iter 211, loss 0.11596, batch_time 0.601
# epoch 2, iter 212, loss 0.11965, batch_time 0.589
# epoch 2, iter 213, loss 0.11354, batch_time 0.650
# epoch 2, iter 214, loss 0.11027, batch_time 0.655
# epoch 2, iter 215, loss 0.11163, batch_time 0.596
# epoch 2, iter 216, loss 0.12265, batch_time 0.657
# epoch 2, iter 217, loss 0.12849, batch_time 0.652
# epoch 2, iter 218, loss 0.12347, batch_time 0.652
# epoch 2, iter 219, loss 0.11364, batch_time 0.597
# epoch 2, iter 220, loss 0.12489, batch_time 0.583
# epoch 2, iter 221, loss 0.10631, batch_time 0.663
# epoch 2, iter 222, loss 0.08599, batch_time 0.651
# epoch 2, iter 223, loss 0.09443, batch_time 0.605
# epoch 2, iter 224, loss 0.11900, batch_time 0.597
# epoch 2, iter 225, loss 0.10226, batch_time 0.604
# epoch 2, iter 226, loss 0.10049, batch_time 0.656
# epoch 2, iter 227, loss 0.09594, batch_time 0.658
# epoch 2, iter 228, loss 0.11106, batch_time 0.643
# epoch 2, iter 229, loss 0.10125, batch_time 0.643
# epoch 2, iter 230, loss 0.07178, batch_time 0.655
# epoch 2, iter 231, loss 0.11159, batch_time 0.581
# epoch 2, iter 232, loss 0.12500, batch_time 0.648
# epoch 2, iter 233, loss 0.12456, batch_time 0.692
# epoch 2, iter 234, loss 0.12419, batch_time 0.606
# epoch 2, iter 235, loss 0.09374, batch_time 0.652
# epoch 2, iter 236, loss 0.09611, batch_time 0.660
# epoch 2, iter 237, loss 0.12992, batch_time 0.602
# epoch 2, iter 238, loss 0.09348, batch_time 0.621
# epoch 2, iter 239, loss 0.09948, batch_time 0.633
# epoch 2, iter 240, loss 0.08534, batch_time 0.645
# epoch 2, iter 241, loss 0.09029, batch_time 0.644
# epoch 2, iter 242, loss 0.13543, batch_time 0.645
# epoch 2, iter 243, loss 0.08556, batch_time 0.649
# epoch 2, iter 244, loss 0.10910, batch_time 0.663
# epoch 2, iter 245, loss 0.09008, batch_time 0.660
# epoch 2, iter 246, loss 0.11458, batch_time 0.659
# epoch 2, iter 247, loss 0.11789, batch_time 0.594
# epoch 2, iter 248, loss 0.09834, batch_time 0.653
# epoch 2, iter 249, loss 0.11768, batch_time 0.650
# epoch 2, iter 250, loss 0.12896, batch_time 0.593
# epoch 2, iter 251, loss 0.10043, batch_time 0.596
# epoch 2, iter 252, loss 0.12083, batch_time 0.593
# epoch 2, iter 253, loss 0.11751, batch_time 0.645
# epoch 2, iter 254, loss 0.08568, batch_time 0.650
# epoch 2, iter 255, loss 0.12091, batch_time 0.585
# epoch 2, iter 256, loss 0.09251, batch_time 0.601
# epoch 2, iter 257, loss 0.10017, batch_time 0.597
# epoch 2, iter 258, loss 0.08798, batch_time 0.600
# epoch 2, iter 259, loss 0.11131, batch_time 0.655
# epoch 2, iter 260, loss 0.11401, batch_time 0.655
# epoch 2, iter 261, loss 0.15359, batch_time 0.598
# epoch 2, iter 262, loss 0.09232, batch_time 0.592
# epoch 2, iter 263, loss 0.10589, batch_time 0.604
# epoch 2, iter 264, loss 0.09054, batch_time 0.604
# epoch 2, iter 265, loss 0.10252, batch_time 0.601
# epoch 2, iter 266, loss 0.13748, batch_time 0.602
# epoch 2, iter 267, loss 0.12788, batch_time 0.687
# epoch 2, iter 268, loss 0.12503, batch_time 0.677
# epoch 2, iter 269, loss 0.10918, batch_time 0.640
# epoch 2, iter 270, loss 0.11215, batch_time 0.649
# epoch 2, iter 271, loss 0.09580, batch_time 0.586
# epoch 2, iter 272, loss 0.09060, batch_time 0.601
# epoch 2, iter 273, loss 0.09911, batch_time 0.600
# epoch 2, iter 274, loss 0.10996, batch_time 0.595
# epoch 2, iter 275, loss 0.09465, batch_time 0.588
# epoch 2, iter 276, loss 0.11790, batch_time 0.610
# epoch 2, iter 277, loss 0.09896, batch_time 0.647
# epoch 2, iter 278, loss 0.11476, batch_time 0.654
# epoch 2, iter 279, loss 0.10003, batch_time 0.587
# epoch 2, iter 280, loss 0.12186, batch_time 0.586
# Train Loss:  15.29797750711441
# Dev Loss:  2.18072447180748
#
# epoch 3, iter 281, loss 0.06936, batch_time 0.631
# epoch 3, iter 282, loss 0.07601, batch_time 0.600
# epoch 3, iter 283, loss 0.05859, batch_time 0.654
# epoch 3, iter 284, loss 0.08106, batch_time 0.650
# epoch 3, iter 285, loss 0.05868, batch_time 0.648
# epoch 3, iter 286, loss 0.05582, batch_time 0.649
# epoch 3, iter 287, loss 0.05861, batch_time 0.673
# epoch 3, iter 288, loss 0.07125, batch_time 0.659
# epoch 3, iter 289, loss 0.04930, batch_time 0.565
# epoch 3, iter 290, loss 0.07206, batch_time 0.574
# epoch 3, iter 291, loss 0.05780, batch_time 0.587
# epoch 3, iter 292, loss 0.07317, batch_time 0.578
# epoch 3, iter 293, loss 0.06379, batch_time 0.606
# epoch 3, iter 294, loss 0.08601, batch_time 0.573
# epoch 3, iter 295, loss 0.06484, batch_time 0.647
# epoch 3, iter 296, loss 0.04468, batch_time 0.565
# epoch 3, iter 297, loss 0.06582, batch_time 0.575
# epoch 3, iter 298, loss 0.07272, batch_time 0.639
# epoch 3, iter 299, loss 0.04974, batch_time 0.645
# epoch 3, iter 300, loss 0.04379, batch_time 0.570
# epoch 3, iter 301, loss 0.08199, batch_time 0.586
# epoch 3, iter 302, loss 0.06375, batch_time 0.594
# epoch 3, iter 303, loss 0.07413, batch_time 0.584
# epoch 3, iter 304, loss 0.07237, batch_time 0.584
# epoch 3, iter 305, loss 0.06394, batch_time 0.606
# epoch 3, iter 306, loss 0.06612, batch_time 0.582
# epoch 3, iter 307, loss 0.05648, batch_time 0.578
# epoch 3, iter 308, loss 0.05839, batch_time 0.604
# epoch 3, iter 309, loss 0.05822, batch_time 0.590
# epoch 3, iter 310, loss 0.06445, batch_time 0.586
# epoch 3, iter 311, loss 0.07297, batch_time 0.583
# epoch 3, iter 312, loss 0.06639, batch_time 0.643
# epoch 3, iter 313, loss 0.06542, batch_time 0.597
# epoch 3, iter 314, loss 0.05392, batch_time 0.595
# epoch 3, iter 315, loss 0.06554, batch_time 0.598
# epoch 3, iter 316, loss 0.04352, batch_time 0.596
# epoch 3, iter 317, loss 0.05310, batch_time 0.662
# epoch 3, iter 318, loss 0.07071, batch_time 0.633
# epoch 3, iter 319, loss 0.04911, batch_time 0.649
# epoch 3, iter 320, loss 0.07226, batch_time 0.636
# epoch 3, iter 321, loss 0.08127, batch_time 0.651
# epoch 3, iter 322, loss 0.04659, batch_time 0.650
# epoch 3, iter 323, loss 0.06561, batch_time 0.600
# epoch 3, iter 324, loss 0.06486, batch_time 0.606
# epoch 3, iter 325, loss 0.06848, batch_time 0.594
# epoch 3, iter 326, loss 0.07857, batch_time 0.597
# epoch 3, iter 327, loss 0.06626, batch_time 0.669
# epoch 3, iter 328, loss 0.05756, batch_time 0.645
# epoch 3, iter 329, loss 0.05403, batch_time 0.650
# epoch 3, iter 330, loss 0.05441, batch_time 0.645
# epoch 3, iter 331, loss 0.04931, batch_time 0.634
# epoch 3, iter 332, loss 0.07060, batch_time 0.615
# epoch 3, iter 333, loss 0.07602, batch_time 0.637
# epoch 3, iter 334, loss 0.07135, batch_time 0.595
# epoch 3, iter 335, loss 0.07262, batch_time 0.605
# epoch 3, iter 336, loss 0.05329, batch_time 0.643
# epoch 3, iter 337, loss 0.07015, batch_time 0.653
# epoch 3, iter 338, loss 0.05336, batch_time 0.658
# epoch 3, iter 339, loss 0.05645, batch_time 0.589
# epoch 3, iter 340, loss 0.07509, batch_time 0.666
# epoch 3, iter 341, loss 0.04719, batch_time 0.658
# epoch 3, iter 342, loss 0.07220, batch_time 0.674
# epoch 3, iter 343, loss 0.05246, batch_time 0.606
# epoch 3, iter 344, loss 0.06793, batch_time 0.663
# epoch 3, iter 345, loss 0.06383, batch_time 0.603
# epoch 3, iter 346, loss 0.05827, batch_time 0.619
# epoch 3, iter 347, loss 0.06992, batch_time 0.609
# epoch 3, iter 348, loss 0.06331, batch_time 0.600
# epoch 3, iter 349, loss 0.07608, batch_time 0.614
# epoch 3, iter 350, loss 0.06624, batch_time 0.607
# epoch 3, iter 351, loss 0.08082, batch_time 0.594
# epoch 3, iter 352, loss 0.05463, batch_time 0.620
# epoch 3, iter 353, loss 0.09258, batch_time 0.665
# epoch 3, iter 354, loss 0.07595, batch_time 0.648
# epoch 3, iter 355, loss 0.05699, batch_time 0.668
# epoch 3, iter 356, loss 0.07980, batch_time 0.654
# epoch 3, iter 357, loss 0.07689, batch_time 0.624
# epoch 3, iter 358, loss 0.06929, batch_time 0.617
# epoch 3, iter 359, loss 0.06456, batch_time 0.695
# epoch 3, iter 360, loss 0.05773, batch_time 0.660
# epoch 3, iter 361, loss 0.06528, batch_time 0.648
# epoch 3, iter 362, loss 0.06569, batch_time 0.669
# epoch 3, iter 363, loss 0.07201, batch_time 0.659
# epoch 3, iter 364, loss 0.09515, batch_time 0.686
# epoch 3, iter 365, loss 0.06542, batch_time 0.667
# epoch 3, iter 366, loss 0.05609, batch_time 0.671
# epoch 3, iter 367, loss 0.06402, batch_time 0.686
# epoch 3, iter 368, loss 0.07568, batch_time 0.618
# epoch 3, iter 369, loss 0.07374, batch_time 0.623
# epoch 3, iter 370, loss 0.06590, batch_time 0.615
# epoch 3, iter 371, loss 0.05904, batch_time 0.613
# epoch 3, iter 372, loss 0.08190, batch_time 0.602
# epoch 3, iter 373, loss 0.07745, batch_time 0.604
# epoch 3, iter 374, loss 0.07435, batch_time 0.607
# epoch 3, iter 375, loss 0.06660, batch_time 0.609
# epoch 3, iter 376, loss 0.05921, batch_time 0.608
# epoch 3, iter 377, loss 0.07421, batch_time 0.602
# epoch 3, iter 378, loss 0.06062, batch_time 0.614
# epoch 3, iter 379, loss 0.07250, batch_time 0.610
# epoch 3, iter 380, loss 0.08975, batch_time 0.611
# epoch 3, iter 381, loss 0.04510, batch_time 0.615
# epoch 3, iter 382, loss 0.05881, batch_time 0.649
# epoch 3, iter 383, loss 0.08878, batch_time 0.689
# epoch 3, iter 384, loss 0.06730, batch_time 0.665
# epoch 3, iter 385, loss 0.05597, batch_time 0.659
# epoch 3, iter 386, loss 0.07737, batch_time 0.666
# epoch 3, iter 387, loss 0.07094, batch_time 0.655
# epoch 3, iter 388, loss 0.06804, batch_time 0.614
# epoch 3, iter 389, loss 0.07743, batch_time 0.687
# epoch 3, iter 390, loss 0.07595, batch_time 0.651
# epoch 3, iter 391, loss 0.07390, batch_time 0.656
# epoch 3, iter 392, loss 0.06385, batch_time 0.664
# epoch 3, iter 393, loss 0.10168, batch_time 0.654
# epoch 3, iter 394, loss 0.07942, batch_time 0.664
# epoch 3, iter 395, loss 0.06010, batch_time 0.663
# epoch 3, iter 396, loss 0.06596, batch_time 0.661
# epoch 3, iter 397, loss 0.04883, batch_time 0.605
# epoch 3, iter 398, loss 0.08225, batch_time 0.640
# epoch 3, iter 399, loss 0.06585, batch_time 0.654
# epoch 3, iter 400, loss 0.06997, batch_time 0.642
# epoch 3, iter 401, loss 0.06100, batch_time 0.635
# epoch 3, iter 402, loss 0.09174, batch_time 0.646
# epoch 3, iter 403, loss 0.06009, batch_time 0.660
# epoch 3, iter 404, loss 0.08188, batch_time 0.655
# epoch 3, iter 405, loss 0.05837, batch_time 0.645
# epoch 3, iter 406, loss 0.05663, batch_time 0.653
# epoch 3, iter 407, loss 0.06586, batch_time 0.661
# epoch 3, iter 408, loss 0.06803, batch_time 0.655
# epoch 3, iter 409, loss 0.05960, batch_time 0.651
# epoch 3, iter 410, loss 0.05363, batch_time 0.650
# epoch 3, iter 411, loss 0.07189, batch_time 0.620
# epoch 3, iter 412, loss 0.06838, batch_time 0.613
# epoch 3, iter 413, loss 0.06084, batch_time 0.606
# epoch 3, iter 414, loss 0.05613, batch_time 0.592
# epoch 3, iter 415, loss 0.04091, batch_time 0.626
# epoch 3, iter 416, loss 0.06328, batch_time 0.603
# epoch 3, iter 417, loss 0.04302, batch_time 0.656
# epoch 3, iter 418, loss 0.07004, batch_time 0.645
# epoch 3, iter 419, loss 0.05651, batch_time 0.606
# epoch 3, iter 420, loss 0.07249, batch_time 0.632
# Train Loss:  9.250901106745005
# Dev Loss:  2.4414302557706833

# %%
preds = deep1.predict(X_rnn['train'][:])

# %%
evaluate(Y_rnn_binary, preds)
# Out:
# p, r, f1: 0.9454, 0.9209, 0.9330
#
# average F1 score: 0.932970

# %%
preds = deep1.predict(X_rnn['dev'][:])

# %%
evaluate(Y_rnn_binary_dev, preds)
# Out:
# p, r, f1: 0.8148, 0.6890, 0.7466
#
# average F1 score: 0.746633

# %% [markdown]
# ## 3. Deep + CE

# %%
deep_ce1 = TfRNNClassifier(
    full_glove_vocab,
    embedding=full_glove_embedding,
    embed_dim=100,
    hidden_dim=50,
    max_length=100,
    hidden_activation=tf.nn.tanh,
    cell_class=tf.nn.rnn_cell.LSTMCell, # LSTM
    train_embedding=True,
    max_iter=2,
    word_length=12,
    bidir_rnn=True, # Bidirectional RNN!
    char_embed=True, # Character Embeddings!
    dropout=0.2,
    eta=0.01,
    eval_every=1,
    experiment_name="BINARY_ALL_deep_ce")

# %%
deep_ce1.fit(X_rnn['train'][:], 
             Y_rnn_binary[:], 
             X_dev=X_rnn['dev'],
             y_dev=Y_rnn_binary_dev)
# Out:
# ./logs/BINARY_ALL_deep_ce
# epoch 1, iter 1, loss 0.79662, batch_time 1.320
# epoch 1, iter 2, loss 0.31445, batch_time 1.151
# epoch 1, iter 3, loss 0.34568, batch_time 1.222
# epoch 1, iter 4, loss 0.32165, batch_time 1.207
# epoch 1, iter 5, loss 0.31944, batch_time 1.237
# epoch 1, iter 6, loss 0.36194, batch_time 1.221
# epoch 1, iter 7, loss 0.30870, batch_time 1.247
# epoch 1, iter 8, loss 0.31016, batch_time 1.200
# epoch 1, iter 9, loss 0.33310, batch_time 1.203
# epoch 1, iter 10, loss 0.32175, batch_time 1.208
# epoch 1, iter 11, loss 0.32617, batch_time 1.146
# epoch 1, iter 12, loss 0.33288, batch_time 1.146
# epoch 1, iter 13, loss 0.28945, batch_time 1.148
# epoch 1, iter 14, loss 0.28806, batch_time 1.157
# epoch 1, iter 15, loss 0.32562, batch_time 1.133
# epoch 1, iter 16, loss 0.29511, batch_time 1.156
# epoch 1, iter 17, loss 0.28357, batch_time 1.181
# epoch 1, iter 18, loss 0.35015, batch_time 1.219
# epoch 1, iter 19, loss 0.29404, batch_time 1.246
# epoch 1, iter 20, loss 0.32139, batch_time 1.235
# epoch 1, iter 21, loss 0.29206, batch_time 1.206
# epoch 1, iter 22, loss 0.28990, batch_time 1.262
# epoch 1, iter 23, loss 0.32965, batch_time 1.212
# epoch 1, iter 24, loss 0.31037, batch_time 1.147
# epoch 1, iter 25, loss 0.29565, batch_time 1.190
# epoch 1, iter 26, loss 0.30348, batch_time 1.153
# epoch 1, iter 27, loss 0.30851, batch_time 1.174
# epoch 1, iter 28, loss 0.31244, batch_time 1.146
# epoch 1, iter 29, loss 0.30068, batch_time 1.158
# epoch 1, iter 30, loss 0.32769, batch_time 1.148
# epoch 1, iter 31, loss 0.28366, batch_time 1.199
# epoch 1, iter 32, loss 0.28828, batch_time 1.201
# epoch 1, iter 33, loss 0.28611, batch_time 1.171
# epoch 1, iter 34, loss 0.30037, batch_time 1.150
# epoch 1, iter 35, loss 0.32319, batch_time 1.149
# epoch 1, iter 36, loss 0.29864, batch_time 1.211
# epoch 1, iter 37, loss 0.29255, batch_time 1.142
# epoch 1, iter 38, loss 0.33839, batch_time 1.177
# epoch 1, iter 39, loss 0.30169, batch_time 1.152
# epoch 1, iter 40, loss 0.28591, batch_time 1.149
# epoch 1, iter 41, loss 0.31219, batch_time 1.156
# epoch 1, iter 42, loss 0.27747, batch_time 1.191
# epoch 1, iter 43, loss 0.28012, batch_time 1.204
# epoch 1, iter 44, loss 0.29039, batch_time 1.203
# epoch 1, iter 45, loss 0.23954, batch_time 1.146
# epoch 1, iter 46, loss 0.29151, batch_time 1.140
# epoch 1, iter 47, loss 0.27114, batch_time 1.223
# epoch 1, iter 48, loss 0.24060, batch_time 1.207
# epoch 1, iter 49, loss 0.25100, batch_time 1.193
# epoch 1, iter 50, loss 0.26910, batch_time 1.146
# epoch 1, iter 51, loss 0.28828, batch_time 1.169
# epoch 1, iter 52, loss 0.24645, batch_time 1.151
# epoch 1, iter 53, loss 0.27161, batch_time 1.246
# epoch 1, iter 54, loss 0.26538, batch_time 1.212
# epoch 1, iter 55, loss 0.23953, batch_time 1.135
# epoch 1, iter 56, loss 0.26364, batch_time 1.226
# epoch 1, iter 57, loss 0.22458, batch_time 1.198
# epoch 1, iter 58, loss 0.29563, batch_time 1.132
# epoch 1, iter 59, loss 0.21462, batch_time 1.135
# epoch 1, iter 60, loss 0.23628, batch_time 1.132
# epoch 1, iter 61, loss 0.25591, batch_time 1.218
# epoch 1, iter 62, loss 0.23145, batch_time 1.190
# epoch 1, iter 63, loss 0.25901, batch_time 1.148
# epoch 1, iter 64, loss 0.21948, batch_time 1.150
# epoch 1, iter 65, loss 0.27368, batch_time 1.140
# epoch 1, iter 66, loss 0.21206, batch_time 1.223
# epoch 1, iter 67, loss 0.24937, batch_time 1.141
# epoch 1, iter 68, loss 0.26164, batch_time 1.134
# epoch 1, iter 69, loss 0.21205, batch_time 1.121
# epoch 1, iter 70, loss 0.23562, batch_time 1.134
# epoch 1, iter 71, loss 0.24759, batch_time 1.135
# epoch 1, iter 72, loss 0.21496, batch_time 1.143
# epoch 1, iter 73, loss 0.22984, batch_time 1.183
# epoch 1, iter 74, loss 0.21475, batch_time 1.137
# epoch 1, iter 75, loss 0.24719, batch_time 1.156
# epoch 1, iter 76, loss 0.24636, batch_time 1.137
# epoch 1, iter 77, loss 0.23873, batch_time 1.130
# epoch 1, iter 78, loss 0.19689, batch_time 1.147
# epoch 1, iter 79, loss 0.25408, batch_time 1.140
# epoch 1, iter 80, loss 0.20773, batch_time 1.132
# epoch 1, iter 81, loss 0.20998, batch_time 1.170
# epoch 1, iter 82, loss 0.22295, batch_time 1.133
# epoch 1, iter 83, loss 0.21008, batch_time 1.224
# epoch 1, iter 84, loss 0.22492, batch_time 1.194
# epoch 1, iter 85, loss 0.22362, batch_time 1.121
# epoch 1, iter 86, loss 0.20283, batch_time 1.123
# epoch 1, iter 87, loss 0.20463, batch_time 1.120
# epoch 1, iter 88, loss 0.22379, batch_time 1.120
# epoch 1, iter 89, loss 0.20409, batch_time 1.134
# epoch 1, iter 90, loss 0.23369, batch_time 1.145
# epoch 1, iter 91, loss 0.19601, batch_time 1.144
# epoch 1, iter 92, loss 0.18730, batch_time 1.134
# epoch 1, iter 93, loss 0.15395, batch_time 1.140
# epoch 1, iter 94, loss 0.19325, batch_time 1.129
# epoch 1, iter 95, loss 0.18174, batch_time 1.122
# epoch 1, iter 96, loss 0.18192, batch_time 1.126
# epoch 1, iter 97, loss 0.19890, batch_time 1.142
# epoch 1, iter 98, loss 0.17685, batch_time 1.138
# epoch 1, iter 99, loss 0.16314, batch_time 1.216
# epoch 1, iter 100, loss 0.16901, batch_time 1.162
# epoch 1, iter 101, loss 0.18561, batch_time 1.152
# epoch 1, iter 102, loss 0.19027, batch_time 1.153
# epoch 1, iter 103, loss 0.18266, batch_time 1.211
# epoch 1, iter 104, loss 0.17124, batch_time 1.141
# epoch 1, iter 105, loss 0.16869, batch_time 1.144
# epoch 1, iter 106, loss 0.17881, batch_time 1.137
# epoch 1, iter 107, loss 0.17194, batch_time 1.201
# epoch 1, iter 108, loss 0.16185, batch_time 1.232
# epoch 1, iter 109, loss 0.17646, batch_time 1.203
# epoch 1, iter 110, loss 0.14014, batch_time 1.146
# epoch 1, iter 111, loss 0.16153, batch_time 1.193
# epoch 1, iter 112, loss 0.18020, batch_time 1.136
# epoch 1, iter 113, loss 0.17916, batch_time 1.148
# epoch 1, iter 114, loss 0.13894, batch_time 1.177
# epoch 1, iter 115, loss 0.13608, batch_time 1.219
# epoch 1, iter 116, loss 0.15775, batch_time 1.129
# epoch 1, iter 117, loss 0.16108, batch_time 1.125
# epoch 1, iter 118, loss 0.16091, batch_time 1.127
# epoch 1, iter 119, loss 0.17066, batch_time 1.125
# epoch 1, iter 120, loss 0.18317, batch_time 1.147
# epoch 1, iter 121, loss 0.16290, batch_time 1.194
# epoch 1, iter 122, loss 0.17690, batch_time 1.128
# epoch 1, iter 123, loss 0.15557, batch_time 1.141
# epoch 1, iter 124, loss 0.16201, batch_time 1.130
# epoch 1, iter 125, loss 0.16396, batch_time 1.134
# epoch 1, iter 126, loss 0.14850, batch_time 1.146
# epoch 1, iter 127, loss 0.18680, batch_time 1.221
# epoch 1, iter 128, loss 0.13729, batch_time 1.150
# epoch 1, iter 129, loss 0.10917, batch_time 1.152
# epoch 1, iter 130, loss 0.17177, batch_time 1.120
# epoch 1, iter 131, loss 0.12927, batch_time 1.192
# epoch 1, iter 132, loss 0.12615, batch_time 1.129
# epoch 1, iter 133, loss 0.12618, batch_time 1.146
# epoch 1, iter 134, loss 0.16012, batch_time 1.141
# epoch 1, iter 135, loss 0.15029, batch_time 1.139
# epoch 1, iter 136, loss 0.16063, batch_time 1.133
# epoch 1, iter 137, loss 0.15101, batch_time 1.127
# epoch 1, iter 138, loss 0.19339, batch_time 1.128
# epoch 1, iter 139, loss 0.13597, batch_time 1.138
# epoch 1, iter 140, loss 0.13730, batch_time 1.090
# Train Loss:  33.2515826895833
# Dev Loss:  2.613444745540619
#
# epoch 2, iter 141, loss 0.11131, batch_time 1.120
# epoch 2, iter 142, loss 0.11929, batch_time 1.133
# epoch 2, iter 143, loss 0.18686, batch_time 1.215
# epoch 2, iter 144, loss 0.11407, batch_time 1.160
# epoch 2, iter 145, loss 0.09657, batch_time 1.136
# epoch 2, iter 146, loss 0.11294, batch_time 1.132
# epoch 2, iter 147, loss 0.12245, batch_time 1.152
# epoch 2, iter 148, loss 0.12010, batch_time 1.139
# epoch 2, iter 149, loss 0.11887, batch_time 1.141
# epoch 2, iter 150, loss 0.13509, batch_time 1.125
# epoch 2, iter 151, loss 0.10950, batch_time 1.141
# epoch 2, iter 152, loss 0.12165, batch_time 1.143
# epoch 2, iter 153, loss 0.12861, batch_time 1.127
# epoch 2, iter 154, loss 0.14180, batch_time 1.134
# epoch 2, iter 155, loss 0.14933, batch_time 1.141
# epoch 2, iter 156, loss 0.12521, batch_time 1.151
# epoch 2, iter 157, loss 0.11636, batch_time 1.122
# epoch 2, iter 158, loss 0.13892, batch_time 1.149
# epoch 2, iter 159, loss 0.12450, batch_time 1.146
# epoch 2, iter 160, loss 0.11532, batch_time 1.143
# epoch 2, iter 161, loss 0.12361, batch_time 1.176
# epoch 2, iter 162, loss 0.10775, batch_time 1.212
# epoch 2, iter 163, loss 0.12219, batch_time 1.137
# epoch 2, iter 164, loss 0.10616, batch_time 1.134
# epoch 2, iter 165, loss 0.11491, batch_time 1.222
# epoch 2, iter 166, loss 0.10369, batch_time 1.206
# epoch 2, iter 167, loss 0.13131, batch_time 1.143
# epoch 2, iter 168, loss 0.13076, batch_time 1.144
# epoch 2, iter 169, loss 0.14296, batch_time 1.228
# epoch 2, iter 170, loss 0.09770, batch_time 1.254
# epoch 2, iter 171, loss 0.11405, batch_time 1.136
# epoch 2, iter 172, loss 0.14052, batch_time 1.157
# epoch 2, iter 173, loss 0.12201, batch_time 1.215
# epoch 2, iter 174, loss 0.10230, batch_time 1.255
# epoch 2, iter 175, loss 0.12177, batch_time 1.199
# epoch 2, iter 176, loss 0.13643, batch_time 1.147
# epoch 2, iter 177, loss 0.11264, batch_time 1.149
# epoch 2, iter 178, loss 0.11135, batch_time 1.135
# epoch 2, iter 179, loss 0.10971, batch_time 1.170
# epoch 2, iter 180, loss 0.14657, batch_time 1.232
# epoch 2, iter 181, loss 0.11642, batch_time 1.142
# epoch 2, iter 182, loss 0.09775, batch_time 1.141
# epoch 2, iter 183, loss 0.12032, batch_time 1.161
# epoch 2, iter 184, loss 0.12640, batch_time 1.146
# epoch 2, iter 185, loss 0.10305, batch_time 1.172
# epoch 2, iter 186, loss 0.10249, batch_time 1.153
# epoch 2, iter 187, loss 0.11997, batch_time 1.125
# epoch 2, iter 188, loss 0.11664, batch_time 1.138
# epoch 2, iter 189, loss 0.13571, batch_time 1.143
# epoch 2, iter 190, loss 0.12080, batch_time 1.128
# epoch 2, iter 191, loss 0.11436, batch_time 1.221
# epoch 2, iter 192, loss 0.13025, batch_time 1.147
# epoch 2, iter 193, loss 0.10539, batch_time 1.118
# epoch 2, iter 194, loss 0.11898, batch_time 1.141
# epoch 2, iter 195, loss 0.10372, batch_time 1.144
# epoch 2, iter 196, loss 0.13848, batch_time 1.136
# epoch 2, iter 197, loss 0.11183, batch_time 1.133
# epoch 2, iter 198, loss 0.09657, batch_time 1.131
# epoch 2, iter 199, loss 0.12782, batch_time 1.151
# epoch 2, iter 200, loss 0.11193, batch_time 1.129
# epoch 2, iter 201, loss 0.11201, batch_time 1.205
# epoch 2, iter 202, loss 0.11769, batch_time 1.124
# epoch 2, iter 203, loss 0.11208, batch_time 1.126
# epoch 2, iter 204, loss 0.10703, batch_time 1.154
# epoch 2, iter 205, loss 0.10305, batch_time 1.200
# epoch 2, iter 206, loss 0.11316, batch_time 1.121
# epoch 2, iter 207, loss 0.15810, batch_time 1.152
# epoch 2, iter 208, loss 0.10068, batch_time 1.216
# epoch 2, iter 209, loss 0.13006, batch_time 1.135
# epoch 2, iter 210, loss 0.11877, batch_time 1.183
# epoch 2, iter 211, loss 0.10442, batch_time 1.142
# epoch 2, iter 212, loss 0.12031, batch_time 1.141
# epoch 2, iter 213, loss 0.12009, batch_time 1.162
# epoch 2, iter 214, loss 0.11053, batch_time 1.216
# epoch 2, iter 215, loss 0.09380, batch_time 1.124
# epoch 2, iter 216, loss 0.11354, batch_time 1.143
# epoch 2, iter 217, loss 0.10729, batch_time 1.130
# epoch 2, iter 218, loss 0.10792, batch_time 1.124
# epoch 2, iter 219, loss 0.11947, batch_time 1.157
# epoch 2, iter 220, loss 0.09939, batch_time 1.216
# epoch 2, iter 221, loss 0.11965, batch_time 1.206
# epoch 2, iter 222, loss 0.11961, batch_time 1.205
# epoch 2, iter 223, loss 0.13343, batch_time 1.135
# epoch 2, iter 224, loss 0.09436, batch_time 1.149
# epoch 2, iter 225, loss 0.13300, batch_time 1.131
# epoch 2, iter 226, loss 0.10857, batch_time 1.133
# epoch 2, iter 227, loss 0.11721, batch_time 1.208
# epoch 2, iter 228, loss 0.14033, batch_time 1.125
# epoch 2, iter 229, loss 0.12873, batch_time 1.145
# epoch 2, iter 230, loss 0.12095, batch_time 1.120
# epoch 2, iter 231, loss 0.12742, batch_time 1.138
# epoch 2, iter 232, loss 0.10858, batch_time 1.158
# epoch 2, iter 233, loss 0.11544, batch_time 1.166
# epoch 2, iter 234, loss 0.10691, batch_time 1.143
# epoch 2, iter 235, loss 0.10517, batch_time 1.132
# epoch 2, iter 236, loss 0.10824, batch_time 1.141
# epoch 2, iter 237, loss 0.10133, batch_time 1.145
# epoch 2, iter 238, loss 0.09517, batch_time 1.128
# epoch 2, iter 239, loss 0.12101, batch_time 1.135
# epoch 2, iter 240, loss 0.07109, batch_time 1.132
# epoch 2, iter 241, loss 0.08720, batch_time 1.211
# epoch 2, iter 242, loss 0.13125, batch_time 1.129
# epoch 2, iter 243, loss 0.10209, batch_time 1.111
# epoch 2, iter 244, loss 0.11513, batch_time 1.132
# epoch 2, iter 245, loss 0.10664, batch_time 1.149
# epoch 2, iter 246, loss 0.10984, batch_time 1.134
# epoch 2, iter 247, loss 0.09675, batch_time 1.150
# epoch 2, iter 248, loss 0.11504, batch_time 1.148
# epoch 2, iter 249, loss 0.11899, batch_time 1.135
# epoch 2, iter 250, loss 0.09811, batch_time 1.146
# epoch 2, iter 251, loss 0.10596, batch_time 1.137
# epoch 2, iter 252, loss 0.13131, batch_time 1.144
# epoch 2, iter 253, loss 0.09011, batch_time 1.149
# epoch 2, iter 254, loss 0.09529, batch_time 1.143
# epoch 2, iter 255, loss 0.14149, batch_time 1.128
# epoch 2, iter 256, loss 0.11430, batch_time 1.127
# epoch 2, iter 257, loss 0.10620, batch_time 1.154
# epoch 2, iter 258, loss 0.11403, batch_time 1.124
# epoch 2, iter 259, loss 0.12128, batch_time 1.129
# epoch 2, iter 260, loss 0.11844, batch_time 1.205
# epoch 2, iter 261, loss 0.09362, batch_time 1.136
# epoch 2, iter 262, loss 0.13314, batch_time 1.131
# epoch 2, iter 263, loss 0.11493, batch_time 1.166
# epoch 2, iter 264, loss 0.09349, batch_time 1.135
# epoch 2, iter 265, loss 0.13398, batch_time 1.123
# epoch 2, iter 266, loss 0.09882, batch_time 1.136
# epoch 2, iter 267, loss 0.12057, batch_time 1.227
# epoch 2, iter 268, loss 0.10490, batch_time 1.173
# epoch 2, iter 269, loss 0.11080, batch_time 1.131
# epoch 2, iter 270, loss 0.11149, batch_time 1.134
# epoch 2, iter 271, loss 0.10760, batch_time 1.120
# epoch 2, iter 272, loss 0.10300, batch_time 1.245
# epoch 2, iter 273, loss 0.12419, batch_time 1.127
# epoch 2, iter 274, loss 0.11115, batch_time 1.138
# epoch 2, iter 275, loss 0.09604, batch_time 1.140
# epoch 2, iter 276, loss 0.12032, batch_time 1.142
# epoch 2, iter 277, loss 0.12176, batch_time 1.128
# epoch 2, iter 278, loss 0.08559, batch_time 1.152
# epoch 2, iter 279, loss 0.11573, batch_time 1.135
# epoch 2, iter 280, loss 0.09472, batch_time 0.919
# Train Loss:  16.186904698610306
# Dev Loss:  2.06329732388258

# %%
preds = deep_ce1.predict(X_rnn['train'][:])

# %%
evaluate(Y_rnn_binary, preds)
# Out:
# p, r, f1: 0.9254, 0.8070, 0.8622
#
# average F1 score: 0.862176

# %%
preds = deep_ce1.predict(X_rnn['dev'][:])

# %%
evaluate(Y_rnn_binary_dev, preds)
# Out:
# p, r, f1: 0.8723, 0.6595, 0.7512
#
# average F1 score: 0.751152

# %% [markdown]
# ## 4. Deep + Self

# %%
deep_self1 = TfRNNClassifier(
    full_glove_vocab,
    embedding=full_glove_embedding,
    embed_dim=100,
    hidden_dim=50,
    max_length=100,
    hidden_activation=tf.nn.tanh,
    cell_class=tf.nn.rnn_cell.LSTMCell, # LSTM
    train_embedding=True,
    max_iter=2,
    word_length=12,
    bidir_rnn=True, # Bidirectional RNN!
    self_attend=True, # Self-Attention!
    dropout=0.2,
    eta=0.01,
    eval_every=1,
    experiment_name="BINARY_ALL_deep_self")

# %%
deep_self1.fit(X_rnn['train'][:], 
               Y_rnn_binary[:], 
               X_dev=X_rnn['dev'],
               y_dev=Y_rnn_binary_dev)
# Out:
# Tensor("concat_1:0", shape=(?, 200, 50), dtype=float32)
# ./logs/BINARY_ALL_deep_self
# epoch 1, iter 1, loss 0.70161, batch_time 0.655
# epoch 1, iter 2, loss 0.37226, batch_time 0.616
# epoch 1, iter 3, loss 0.33144, batch_time 0.607
# epoch 1, iter 4, loss 0.28658, batch_time 0.599
# epoch 1, iter 5, loss 0.37834, batch_time 0.592
# epoch 1, iter 6, loss 0.30250, batch_time 0.587
# epoch 1, iter 7, loss 0.34485, batch_time 0.611
# epoch 1, iter 8, loss 0.29862, batch_time 0.600
# epoch 1, iter 9, loss 0.31589, batch_time 0.662
# epoch 1, iter 10, loss 0.29424, batch_time 0.670
# epoch 1, iter 11, loss 0.30892, batch_time 0.657
# epoch 1, iter 12, loss 0.28761, batch_time 0.667
# epoch 1, iter 13, loss 0.31388, batch_time 0.647
# epoch 1, iter 14, loss 0.26492, batch_time 0.592
# epoch 1, iter 15, loss 0.25105, batch_time 0.659
# epoch 1, iter 16, loss 0.26089, batch_time 0.672
# epoch 1, iter 17, loss 0.27550, batch_time 0.606
# epoch 1, iter 18, loss 0.23450, batch_time 0.607
# epoch 1, iter 19, loss 0.29858, batch_time 0.596
# epoch 1, iter 20, loss 0.27693, batch_time 0.609
# epoch 1, iter 21, loss 0.26496, batch_time 0.603
# epoch 1, iter 22, loss 0.26529, batch_time 0.658
# epoch 1, iter 23, loss 0.25012, batch_time 0.660
# epoch 1, iter 24, loss 0.25452, batch_time 0.639
# epoch 1, iter 25, loss 0.26923, batch_time 0.653
# epoch 1, iter 26, loss 0.26325, batch_time 0.679
# epoch 1, iter 27, loss 0.25205, batch_time 0.603
# epoch 1, iter 28, loss 0.24049, batch_time 0.607
# epoch 1, iter 29, loss 0.21440, batch_time 0.604
# epoch 1, iter 30, loss 0.25068, batch_time 0.645
# epoch 1, iter 31, loss 0.24831, batch_time 0.649
# epoch 1, iter 32, loss 0.24617, batch_time 0.664
# epoch 1, iter 33, loss 0.25396, batch_time 0.595
# epoch 1, iter 34, loss 0.24138, batch_time 0.587
# epoch 1, iter 35, loss 0.22236, batch_time 0.659
# epoch 1, iter 36, loss 0.20752, batch_time 0.643
# epoch 1, iter 37, loss 0.21728, batch_time 0.707
# epoch 1, iter 38, loss 0.21554, batch_time 0.676
# epoch 1, iter 39, loss 0.21852, batch_time 0.625
# epoch 1, iter 40, loss 0.20935, batch_time 0.640
# epoch 1, iter 41, loss 0.19188, batch_time 0.604
# epoch 1, iter 42, loss 0.21269, batch_time 0.673
# epoch 1, iter 43, loss 0.19372, batch_time 0.678
# epoch 1, iter 44, loss 0.22863, batch_time 0.641
# epoch 1, iter 45, loss 0.21269, batch_time 0.676
# epoch 1, iter 46, loss 0.23838, batch_time 0.635
# epoch 1, iter 47, loss 0.17920, batch_time 0.653
# epoch 1, iter 48, loss 0.21678, batch_time 0.660
# epoch 1, iter 49, loss 0.18316, batch_time 0.587
# epoch 1, iter 50, loss 0.22177, batch_time 0.593
# epoch 1, iter 51, loss 0.21386, batch_time 0.586
# epoch 1, iter 52, loss 0.16683, batch_time 0.589
# epoch 1, iter 53, loss 0.19197, batch_time 0.634
# epoch 1, iter 54, loss 0.18321, batch_time 0.590
# epoch 1, iter 55, loss 0.22557, batch_time 0.610
# epoch 1, iter 56, loss 0.16664, batch_time 0.598
# epoch 1, iter 57, loss 0.20962, batch_time 0.602
# epoch 1, iter 58, loss 0.18674, batch_time 0.601
# epoch 1, iter 59, loss 0.18395, batch_time 0.607
# epoch 1, iter 60, loss 0.13535, batch_time 0.597
# epoch 1, iter 61, loss 0.18981, batch_time 0.662
# epoch 1, iter 62, loss 0.18155, batch_time 0.649
# epoch 1, iter 63, loss 0.15702, batch_time 0.649
# epoch 1, iter 64, loss 0.16267, batch_time 0.598
# epoch 1, iter 65, loss 0.19033, batch_time 0.643
# epoch 1, iter 66, loss 0.17038, batch_time 0.659
# epoch 1, iter 67, loss 0.18179, batch_time 0.609
# epoch 1, iter 68, loss 0.16893, batch_time 0.602
# epoch 1, iter 69, loss 0.16000, batch_time 0.598
# epoch 1, iter 70, loss 0.13728, batch_time 0.607
# epoch 1, iter 71, loss 0.17403, batch_time 0.628
# epoch 1, iter 72, loss 0.18654, batch_time 0.660
# epoch 1, iter 73, loss 0.13958, batch_time 0.658
# epoch 1, iter 74, loss 0.17244, batch_time 0.606
# epoch 1, iter 75, loss 0.16434, batch_time 0.619
# epoch 1, iter 76, loss 0.17530, batch_time 0.626
# epoch 1, iter 77, loss 0.17357, batch_time 0.606
# epoch 1, iter 78, loss 0.17437, batch_time 0.627
# epoch 1, iter 79, loss 0.13246, batch_time 0.614
# epoch 1, iter 80, loss 0.17171, batch_time 0.636
# epoch 1, iter 81, loss 0.19854, batch_time 0.703
# epoch 1, iter 82, loss 0.18424, batch_time 0.667
# epoch 1, iter 83, loss 0.17564, batch_time 0.676
# epoch 1, iter 84, loss 0.14218, batch_time 0.618
# epoch 1, iter 85, loss 0.16629, batch_time 0.676
# epoch 1, iter 86, loss 0.14521, batch_time 0.653
# epoch 1, iter 87, loss 0.15944, batch_time 0.606
# epoch 1, iter 88, loss 0.15140, batch_time 0.598
# epoch 1, iter 89, loss 0.13599, batch_time 0.607
# epoch 1, iter 90, loss 0.15251, batch_time 0.592
# epoch 1, iter 91, loss 0.17270, batch_time 0.598
# epoch 1, iter 92, loss 0.14445, batch_time 0.625
# epoch 1, iter 93, loss 0.16013, batch_time 0.624
# epoch 1, iter 94, loss 0.15326, batch_time 0.604
# epoch 1, iter 95, loss 0.16443, batch_time 0.612
# epoch 1, iter 96, loss 0.17617, batch_time 0.617
# epoch 1, iter 97, loss 0.15355, batch_time 0.622
# epoch 1, iter 98, loss 0.15787, batch_time 0.609
# epoch 1, iter 99, loss 0.15949, batch_time 0.606
# epoch 1, iter 100, loss 0.15526, batch_time 0.609
# epoch 1, iter 101, loss 0.15669, batch_time 0.617
# epoch 1, iter 102, loss 0.17490, batch_time 0.670
# epoch 1, iter 103, loss 0.13698, batch_time 0.608
# epoch 1, iter 104, loss 0.16749, batch_time 0.661
# epoch 1, iter 105, loss 0.13527, batch_time 0.605
# epoch 1, iter 106, loss 0.14831, batch_time 0.664
# epoch 1, iter 107, loss 0.14939, batch_time 0.659
# epoch 1, iter 108, loss 0.13036, batch_time 0.609
# epoch 1, iter 109, loss 0.16882, batch_time 0.674
# epoch 1, iter 110, loss 0.14865, batch_time 0.654
# epoch 1, iter 111, loss 0.14763, batch_time 0.618
# epoch 1, iter 112, loss 0.15731, batch_time 0.602
# epoch 1, iter 113, loss 0.18412, batch_time 0.620
# epoch 1, iter 114, loss 0.14278, batch_time 0.614
# epoch 1, iter 115, loss 0.13316, batch_time 0.620
# epoch 1, iter 116, loss 0.17696, batch_time 0.604
# epoch 1, iter 117, loss 0.12844, batch_time 0.617
# epoch 1, iter 118, loss 0.17390, batch_time 0.602
# epoch 1, iter 119, loss 0.13567, batch_time 0.608
# epoch 1, iter 120, loss 0.14581, batch_time 0.620
# epoch 1, iter 121, loss 0.16966, batch_time 0.674
# epoch 1, iter 122, loss 0.15645, batch_time 0.671
# epoch 1, iter 123, loss 0.13393, batch_time 0.593
# epoch 1, iter 124, loss 0.14464, batch_time 0.595
# epoch 1, iter 125, loss 0.14632, batch_time 0.607
# epoch 1, iter 126, loss 0.15377, batch_time 0.598
# epoch 1, iter 127, loss 0.15347, batch_time 0.621
# epoch 1, iter 128, loss 0.14879, batch_time 0.629
# epoch 1, iter 129, loss 0.14143, batch_time 0.611
# epoch 1, iter 130, loss 0.15665, batch_time 0.606
# epoch 1, iter 131, loss 0.16801, batch_time 0.628
# epoch 1, iter 132, loss 0.14249, batch_time 0.611
# epoch 1, iter 133, loss 0.12414, batch_time 0.660
# epoch 1, iter 134, loss 0.10985, batch_time 0.653
# epoch 1, iter 135, loss 0.14432, batch_time 0.684
# epoch 1, iter 136, loss 0.12124, batch_time 0.695
# epoch 1, iter 137, loss 0.15240, batch_time 0.598
# epoch 1, iter 138, loss 0.14006, batch_time 0.675
# epoch 1, iter 139, loss 0.14612, batch_time 0.616
# epoch 1, iter 140, loss 0.13021, batch_time 0.581
# Train Loss:  27.646591186523438
# Dev Loss:  2.3221946135163307
#
# epoch 2, iter 141, loss 0.11129, batch_time 0.654
# epoch 2, iter 142, loss 0.12966, batch_time 0.678
# epoch 2, iter 143, loss 0.10565, batch_time 0.689
# epoch 2, iter 144, loss 0.10869, batch_time 0.618
# epoch 2, iter 145, loss 0.10882, batch_time 0.608
# epoch 2, iter 146, loss 0.08817, batch_time 0.696
# epoch 2, iter 147, loss 0.13976, batch_time 0.597
# epoch 2, iter 148, loss 0.12285, batch_time 0.599
# epoch 2, iter 149, loss 0.10434, batch_time 0.670
# epoch 2, iter 150, loss 0.11213, batch_time 0.605
# epoch 2, iter 151, loss 0.12584, batch_time 0.625
# epoch 2, iter 152, loss 0.13457, batch_time 0.603
# epoch 2, iter 153, loss 0.11230, batch_time 0.599
# epoch 2, iter 154, loss 0.11370, batch_time 0.594
# epoch 2, iter 155, loss 0.10516, batch_time 0.598
# epoch 2, iter 156, loss 0.12060, batch_time 0.607
# epoch 2, iter 157, loss 0.08090, batch_time 0.608
# epoch 2, iter 158, loss 0.09245, batch_time 0.605
# epoch 2, iter 159, loss 0.12449, batch_time 0.591
# epoch 2, iter 160, loss 0.08925, batch_time 0.605
# epoch 2, iter 161, loss 0.11691, batch_time 0.597
# epoch 2, iter 162, loss 0.11877, batch_time 0.595
# epoch 2, iter 163, loss 0.10541, batch_time 0.618
# epoch 2, iter 164, loss 0.09779, batch_time 0.593
# epoch 2, iter 165, loss 0.12036, batch_time 0.595
# epoch 2, iter 166, loss 0.10712, batch_time 0.605
# epoch 2, iter 167, loss 0.09346, batch_time 0.609
# epoch 2, iter 168, loss 0.10070, batch_time 0.610
# epoch 2, iter 169, loss 0.09405, batch_time 0.612
# epoch 2, iter 170, loss 0.10252, batch_time 0.633
# epoch 2, iter 171, loss 0.09604, batch_time 0.665
# epoch 2, iter 172, loss 0.09954, batch_time 0.675
# epoch 2, iter 173, loss 0.10889, batch_time 0.663
# epoch 2, iter 174, loss 0.09229, batch_time 0.678
# epoch 2, iter 175, loss 0.10316, batch_time 0.627
# epoch 2, iter 176, loss 0.10481, batch_time 0.617
# epoch 2, iter 177, loss 0.08980, batch_time 0.616
# epoch 2, iter 178, loss 0.10258, batch_time 0.673
# epoch 2, iter 179, loss 0.09741, batch_time 0.664
# epoch 2, iter 180, loss 0.09519, batch_time 0.615
# epoch 2, iter 181, loss 0.11558, batch_time 0.667
# epoch 2, iter 182, loss 0.12764, batch_time 0.597
# epoch 2, iter 183, loss 0.11279, batch_time 0.667
# epoch 2, iter 184, loss 0.14068, batch_time 0.597
# epoch 2, iter 185, loss 0.12058, batch_time 0.607
# epoch 2, iter 186, loss 0.11996, batch_time 0.604
# epoch 2, iter 187, loss 0.12168, batch_time 0.657
# epoch 2, iter 188, loss 0.12182, batch_time 0.656
# epoch 2, iter 189, loss 0.09205, batch_time 0.615
# epoch 2, iter 190, loss 0.09646, batch_time 0.657
# epoch 2, iter 191, loss 0.12064, batch_time 0.659
# epoch 2, iter 192, loss 0.11381, batch_time 0.659
# epoch 2, iter 193, loss 0.11611, batch_time 0.591
# epoch 2, iter 194, loss 0.10106, batch_time 0.617
# epoch 2, iter 195, loss 0.10099, batch_time 0.653
# epoch 2, iter 196, loss 0.11044, batch_time 0.618
# epoch 2, iter 197, loss 0.10352, batch_time 0.660
# epoch 2, iter 198, loss 0.11282, batch_time 0.675
# epoch 2, iter 199, loss 0.10725, batch_time 0.596
# epoch 2, iter 200, loss 0.11780, batch_time 0.628
# epoch 2, iter 201, loss 0.14266, batch_time 0.603
# epoch 2, iter 202, loss 0.11739, batch_time 0.656
# epoch 2, iter 203, loss 0.11930, batch_time 0.652
# epoch 2, iter 204, loss 0.13144, batch_time 0.647
# epoch 2, iter 205, loss 0.09758, batch_time 0.600
# epoch 2, iter 206, loss 0.11375, batch_time 0.597
# epoch 2, iter 207, loss 0.11290, batch_time 0.685
# epoch 2, iter 208, loss 0.12515, batch_time 0.648
# epoch 2, iter 209, loss 0.11336, batch_time 0.655
# epoch 2, iter 210, loss 0.10092, batch_time 0.655
# epoch 2, iter 211, loss 0.10745, batch_time 0.595
# epoch 2, iter 212, loss 0.11802, batch_time 0.589
# epoch 2, iter 213, loss 0.08642, batch_time 0.600
# epoch 2, iter 214, loss 0.10958, batch_time 0.596
# epoch 2, iter 215, loss 0.11560, batch_time 0.607
# epoch 2, iter 216, loss 0.10814, batch_time 0.647
# epoch 2, iter 217, loss 0.09831, batch_time 0.632
# epoch 2, iter 218, loss 0.10393, batch_time 0.605
# epoch 2, iter 219, loss 0.09291, batch_time 0.656
# epoch 2, iter 220, loss 0.10571, batch_time 0.604
# epoch 2, iter 221, loss 0.10125, batch_time 0.654
# epoch 2, iter 222, loss 0.10052, batch_time 0.658
# epoch 2, iter 223, loss 0.13014, batch_time 0.671
# epoch 2, iter 224, loss 0.10896, batch_time 0.631
# epoch 2, iter 225, loss 0.10767, batch_time 0.613
# epoch 2, iter 226, loss 0.12517, batch_time 0.670
# epoch 2, iter 227, loss 0.09711, batch_time 0.667
# epoch 2, iter 228, loss 0.12156, batch_time 0.651
# epoch 2, iter 229, loss 0.11194, batch_time 0.656
# epoch 2, iter 230, loss 0.10146, batch_time 0.607
# epoch 2, iter 231, loss 0.09291, batch_time 0.663
# epoch 2, iter 232, loss 0.11760, batch_time 0.661
# epoch 2, iter 233, loss 0.10194, batch_time 0.637
# epoch 2, iter 234, loss 0.11757, batch_time 0.663
# epoch 2, iter 235, loss 0.09524, batch_time 0.608
# epoch 2, iter 236, loss 0.09805, batch_time 0.640
# epoch 2, iter 237, loss 0.08190, batch_time 0.623
# epoch 2, iter 238, loss 0.09825, batch_time 0.677
# epoch 2, iter 239, loss 0.09624, batch_time 0.601
# epoch 2, iter 240, loss 0.10861, batch_time 0.603
# epoch 2, iter 241, loss 0.08851, batch_time 0.680
# epoch 2, iter 242, loss 0.08709, batch_time 0.673
# epoch 2, iter 243, loss 0.08066, batch_time 0.680
# epoch 2, iter 244, loss 0.10124, batch_time 0.661
# epoch 2, iter 245, loss 0.10894, batch_time 0.614
# epoch 2, iter 246, loss 0.10992, batch_time 0.604
# epoch 2, iter 247, loss 0.11095, batch_time 0.656
# epoch 2, iter 248, loss 0.10682, batch_time 0.648
# epoch 2, iter 249, loss 0.10054, batch_time 0.656
# epoch 2, iter 250, loss 0.08913, batch_time 0.609
# epoch 2, iter 251, loss 0.10019, batch_time 0.615
# epoch 2, iter 252, loss 0.09973, batch_time 0.606
# epoch 2, iter 253, loss 0.11094, batch_time 0.602
# epoch 2, iter 254, loss 0.12025, batch_time 0.619
# epoch 2, iter 255, loss 0.08869, batch_time 0.602
# epoch 2, iter 256, loss 0.09321, batch_time 0.595
# epoch 2, iter 257, loss 0.10365, batch_time 0.597
# epoch 2, iter 258, loss 0.10066, batch_time 0.656
# epoch 2, iter 259, loss 0.10603, batch_time 0.662
# epoch 2, iter 260, loss 0.08592, batch_time 0.598
# epoch 2, iter 261, loss 0.09194, batch_time 0.594
# epoch 2, iter 262, loss 0.09290, batch_time 0.686
# epoch 2, iter 263, loss 0.09770, batch_time 0.655
# epoch 2, iter 264, loss 0.10739, batch_time 0.663
# epoch 2, iter 265, loss 0.09472, batch_time 0.624
# epoch 2, iter 266, loss 0.12968, batch_time 0.625
# epoch 2, iter 267, loss 0.09727, batch_time 0.615
# epoch 2, iter 268, loss 0.10908, batch_time 0.601
# epoch 2, iter 269, loss 0.09777, batch_time 0.673
# epoch 2, iter 270, loss 0.09156, batch_time 0.610
# epoch 2, iter 271, loss 0.07893, batch_time 0.659
# epoch 2, iter 272, loss 0.11225, batch_time 0.665
# epoch 2, iter 273, loss 0.10538, batch_time 0.608
# epoch 2, iter 274, loss 0.08242, batch_time 0.594
# epoch 2, iter 275, loss 0.08832, batch_time 0.619
# epoch 2, iter 276, loss 0.10864, batch_time 0.669
# epoch 2, iter 277, loss 0.11076, batch_time 0.662
# epoch 2, iter 278, loss 0.10649, batch_time 0.671
# epoch 2, iter 279, loss 0.10928, batch_time 0.660
# epoch 2, iter 280, loss 0.08421, batch_time 0.645
# Train Loss:  14.87548267096281
# Dev Loss:  2.199625737965107

# %%
preds = deep_self1.predict(X_rnn['train'][:])

# %%
evaluate(Y_rnn_binary, preds)
# Out:
# p, r, f1: 0.9175, 0.8366, 0.8752
#
# average F1 score: 0.875185

# %%
preds = deep_self1.predict(X_rnn['dev'][:])

# %%
evaluate(Y_rnn_binary_dev, preds)
# Out:
# p, r, f1: 0.8463, 0.6746, 0.7507
#
# average F1 score: 0.750724

# %% [markdown]
# ## 5. Deep + CE + Attention

# %%
deep_ce_self1 = TfRNNClassifier(
    full_glove_vocab,
    embedding=full_glove_embedding,
    embed_dim=100,
    hidden_dim=50,
    max_length=100,
    hidden_activation=tf.nn.tanh,
    cell_class=tf.nn.rnn_cell.LSTMCell, # LSTM
    train_embedding=True,
    max_iter=2,
    word_length=12,
    bidir_rnn=True, # Bidirectional RNN
    char_embed=True, # Character Embeddings
    self_attend=True, # Self-Attention
    dropout=0.2,
    eta=0.01,
    eval_every=1,
    experiment_name="BINARY_ALL_deep_ce_self")

# %%
deep_ce_self1.fit(X_rnn['train'][:], 
                      Y_rnn_binary[:], 
                      X_dev=X_rnn['dev'],
                      y_dev=Y_rnn_binary_dev)
# Out:
# Tensor("concat_2:0", shape=(?, 200, 50), dtype=float32)
# ./logs/BINARY_ALL_deep_ce_self
# epoch 1, iter 1, loss 0.86763, batch_time 1.142
# epoch 1, iter 2, loss 0.37050, batch_time 1.135
# epoch 1, iter 3, loss 0.34039, batch_time 1.155
# epoch 1, iter 4, loss 0.34038, batch_time 1.178
# epoch 1, iter 5, loss 0.35133, batch_time 1.157
# epoch 1, iter 6, loss 0.34788, batch_time 1.170
# epoch 1, iter 7, loss 0.33005, batch_time 1.176
# epoch 1, iter 8, loss 0.34250, batch_time 1.244
# epoch 1, iter 9, loss 0.30581, batch_time 1.228
# epoch 1, iter 10, loss 0.36925, batch_time 1.238
# epoch 1, iter 11, loss 0.34285, batch_time 1.179
# epoch 1, iter 12, loss 0.35470, batch_time 1.170
# epoch 1, iter 13, loss 0.34715, batch_time 1.174
# epoch 1, iter 14, loss 0.34091, batch_time 1.221
# epoch 1, iter 15, loss 0.34537, batch_time 1.237
# epoch 1, iter 16, loss 0.36096, batch_time 1.155
# epoch 1, iter 17, loss 0.33024, batch_time 1.163
# epoch 1, iter 18, loss 0.30658, batch_time 1.162
# epoch 1, iter 19, loss 0.34225, batch_time 1.144
# epoch 1, iter 20, loss 0.37391, batch_time 1.155
# epoch 1, iter 21, loss 0.35233, batch_time 1.209
# epoch 1, iter 22, loss 0.29224, batch_time 1.176
# epoch 1, iter 23, loss 0.30803, batch_time 1.167
# epoch 1, iter 24, loss 0.31081, batch_time 1.226
# epoch 1, iter 25, loss 0.31849, batch_time 1.157
# epoch 1, iter 26, loss 0.33547, batch_time 1.175
# epoch 1, iter 27, loss 0.29472, batch_time 1.165
# epoch 1, iter 28, loss 0.33454, batch_time 1.221
# epoch 1, iter 29, loss 0.35925, batch_time 1.235
# epoch 1, iter 30, loss 0.31081, batch_time 1.218
# epoch 1, iter 31, loss 0.31880, batch_time 1.229
# epoch 1, iter 32, loss 0.30843, batch_time 1.157
# epoch 1, iter 33, loss 0.32200, batch_time 1.238
# epoch 1, iter 34, loss 0.36660, batch_time 1.228
# epoch 1, iter 35, loss 0.32120, batch_time 1.204
# epoch 1, iter 36, loss 0.30251, batch_time 1.227
# epoch 1, iter 37, loss 0.29221, batch_time 1.220
# epoch 1, iter 38, loss 0.32466, batch_time 1.231
# epoch 1, iter 39, loss 0.32234, batch_time 1.218
# epoch 1, iter 40, loss 0.35071, batch_time 1.148
# epoch 1, iter 41, loss 0.32958, batch_time 1.189
# epoch 1, iter 42, loss 0.35405, batch_time 1.159
# epoch 1, iter 43, loss 0.34412, batch_time 1.154
# epoch 1, iter 44, loss 0.27954, batch_time 1.166
# epoch 1, iter 45, loss 0.28756, batch_time 1.228
# epoch 1, iter 46, loss 0.31411, batch_time 1.205
# epoch 1, iter 47, loss 0.32860, batch_time 1.224
# epoch 1, iter 48, loss 0.31339, batch_time 1.216
# epoch 1, iter 49, loss 0.32930, batch_time 1.151
# epoch 1, iter 50, loss 0.30499, batch_time 1.211
# epoch 1, iter 51, loss 0.28133, batch_time 1.164
# epoch 1, iter 52, loss 0.28966, batch_time 1.144
# epoch 1, iter 53, loss 0.26827, batch_time 1.155
# epoch 1, iter 54, loss 0.25012, batch_time 1.156
# epoch 1, iter 55, loss 0.30304, batch_time 1.163
# epoch 1, iter 56, loss 0.30213, batch_time 1.136
# epoch 1, iter 57, loss 0.31722, batch_time 1.156
# epoch 1, iter 58, loss 0.30709, batch_time 1.146
# epoch 1, iter 59, loss 0.32139, batch_time 1.147
# epoch 1, iter 60, loss 0.26955, batch_time 1.157
# epoch 1, iter 61, loss 0.27503, batch_time 1.155
# epoch 1, iter 62, loss 0.27906, batch_time 1.160
# epoch 1, iter 63, loss 0.25383, batch_time 1.201
# epoch 1, iter 64, loss 0.31209, batch_time 1.141
# epoch 1, iter 65, loss 0.26210, batch_time 1.157
# epoch 1, iter 66, loss 0.28600, batch_time 1.232
# epoch 1, iter 67, loss 0.30112, batch_time 1.225
# epoch 1, iter 68, loss 0.28816, batch_time 1.148
# epoch 1, iter 69, loss 0.26635, batch_time 1.225
# epoch 1, iter 70, loss 0.27143, batch_time 1.253
# epoch 1, iter 71, loss 0.28927, batch_time 1.213
# epoch 1, iter 72, loss 0.28429, batch_time 1.215
# epoch 1, iter 73, loss 0.26920, batch_time 1.196
# epoch 1, iter 74, loss 0.31747, batch_time 1.164
# epoch 1, iter 75, loss 0.26427, batch_time 1.292
# epoch 1, iter 76, loss 0.26390, batch_time 1.142
# epoch 1, iter 77, loss 0.24756, batch_time 1.168
# epoch 1, iter 78, loss 0.23377, batch_time 1.150
# epoch 1, iter 79, loss 0.29154, batch_time 1.159
# epoch 1, iter 80, loss 0.30840, batch_time 1.207
# epoch 1, iter 81, loss 0.26314, batch_time 1.156
# epoch 1, iter 82, loss 0.25270, batch_time 1.163
# epoch 1, iter 83, loss 0.23590, batch_time 1.234
# epoch 1, iter 84, loss 0.24901, batch_time 1.235
# epoch 1, iter 85, loss 0.26553, batch_time 1.238
# epoch 1, iter 86, loss 0.24983, batch_time 1.240
# epoch 1, iter 87, loss 0.21989, batch_time 1.232
# epoch 1, iter 88, loss 0.23295, batch_time 1.198
# epoch 1, iter 89, loss 0.22372, batch_time 1.222
# epoch 1, iter 90, loss 0.25987, batch_time 1.252
# epoch 1, iter 91, loss 0.22615, batch_time 1.218
# epoch 1, iter 92, loss 0.21569, batch_time 1.227
# epoch 1, iter 93, loss 0.21914, batch_time 1.233
# epoch 1, iter 94, loss 0.20837, batch_time 1.212
# epoch 1, iter 95, loss 0.24406, batch_time 1.225
# epoch 1, iter 96, loss 0.22363, batch_time 1.207
# epoch 1, iter 97, loss 0.21789, batch_time 1.194
# epoch 1, iter 98, loss 0.18361, batch_time 1.212
# epoch 1, iter 99, loss 0.24128, batch_time 1.223
# epoch 1, iter 100, loss 0.20645, batch_time 1.170
# epoch 1, iter 101, loss 0.23235, batch_time 1.152
# epoch 1, iter 102, loss 0.23283, batch_time 1.162
# epoch 1, iter 103, loss 0.23198, batch_time 1.208
# epoch 1, iter 104, loss 0.18890, batch_time 1.212
# epoch 1, iter 105, loss 0.21498, batch_time 1.168
# epoch 1, iter 106, loss 0.20482, batch_time 1.162
# epoch 1, iter 107, loss 0.22647, batch_time 1.217
# epoch 1, iter 108, loss 0.22132, batch_time 1.199
# epoch 1, iter 109, loss 0.18388, batch_time 1.191
# epoch 1, iter 110, loss 0.20328, batch_time 1.239
# epoch 1, iter 111, loss 0.19872, batch_time 1.216
# epoch 1, iter 112, loss 0.19760, batch_time 1.225
# epoch 1, iter 113, loss 0.19784, batch_time 1.219
# epoch 1, iter 114, loss 0.18122, batch_time 1.199
# epoch 1, iter 115, loss 0.21025, batch_time 1.196
# epoch 1, iter 116, loss 0.19234, batch_time 1.225
# epoch 1, iter 117, loss 0.24159, batch_time 1.225
# epoch 1, iter 118, loss 0.18658, batch_time 1.174
# epoch 1, iter 119, loss 0.16986, batch_time 1.153
# epoch 1, iter 120, loss 0.19407, batch_time 1.228
# epoch 1, iter 121, loss 0.17402, batch_time 1.222
# epoch 1, iter 122, loss 0.20522, batch_time 1.207
# epoch 1, iter 123, loss 0.20962, batch_time 1.215
# epoch 1, iter 124, loss 0.19464, batch_time 1.174
# epoch 1, iter 125, loss 0.18471, batch_time 1.210
# epoch 1, iter 126, loss 0.18326, batch_time 1.219
# epoch 1, iter 127, loss 0.17620, batch_time 1.245
# epoch 1, iter 128, loss 0.19018, batch_time 1.231
# epoch 1, iter 129, loss 0.19361, batch_time 1.173
# epoch 1, iter 130, loss 0.17203, batch_time 1.158
# epoch 1, iter 131, loss 0.17720, batch_time 1.172
# epoch 1, iter 132, loss 0.20874, batch_time 1.159
# epoch 1, iter 133, loss 0.16106, batch_time 1.215
# epoch 1, iter 134, loss 0.15944, batch_time 1.177
# epoch 1, iter 135, loss 0.18242, batch_time 1.178
# epoch 1, iter 136, loss 0.15051, batch_time 1.243
# epoch 1, iter 137, loss 0.21167, batch_time 1.175
# epoch 1, iter 138, loss 0.17998, batch_time 1.155
# epoch 1, iter 139, loss 0.19412, batch_time 1.141
# epoch 1, iter 140, loss 0.16593, batch_time 0.960
# Train Loss:  37.940888464450836
# Dev Loss:  3.0219483375549316
#
# epoch 2, iter 141, loss 0.18125, batch_time 1.212
# epoch 2, iter 142, loss 0.17474, batch_time 1.219
# epoch 2, iter 143, loss 0.15844, batch_time 1.156
# epoch 2, iter 144, loss 0.17358, batch_time 1.170
# epoch 2, iter 145, loss 0.15801, batch_time 1.169
# epoch 2, iter 146, loss 0.15537, batch_time 1.172
# epoch 2, iter 147, loss 0.16816, batch_time 1.161
# epoch 2, iter 148, loss 0.14465, batch_time 1.212
# epoch 2, iter 149, loss 0.15083, batch_time 1.201
# epoch 2, iter 150, loss 0.14648, batch_time 1.159
# epoch 2, iter 151, loss 0.14523, batch_time 1.147
# epoch 2, iter 152, loss 0.12592, batch_time 1.217
# epoch 2, iter 153, loss 0.14993, batch_time 1.220
# epoch 2, iter 154, loss 0.14514, batch_time 1.150
# epoch 2, iter 155, loss 0.14858, batch_time 1.141
# epoch 2, iter 156, loss 0.14552, batch_time 1.219
# epoch 2, iter 157, loss 0.15307, batch_time 1.151
# epoch 2, iter 158, loss 0.14591, batch_time 1.154
# epoch 2, iter 159, loss 0.13961, batch_time 1.225
# epoch 2, iter 160, loss 0.13957, batch_time 1.213
# epoch 2, iter 161, loss 0.12633, batch_time 1.230
# epoch 2, iter 162, loss 0.12954, batch_time 1.273
# epoch 2, iter 163, loss 0.13830, batch_time 1.226
# epoch 2, iter 164, loss 0.11742, batch_time 1.230
# epoch 2, iter 165, loss 0.13064, batch_time 1.159
# epoch 2, iter 166, loss 0.15081, batch_time 1.155
# epoch 2, iter 167, loss 0.12281, batch_time 1.241
# epoch 2, iter 168, loss 0.13374, batch_time 1.156
# epoch 2, iter 169, loss 0.16226, batch_time 1.147
# epoch 2, iter 170, loss 0.14264, batch_time 1.145
# epoch 2, iter 171, loss 0.12870, batch_time 1.166
# epoch 2, iter 172, loss 0.12534, batch_time 1.181
# epoch 2, iter 173, loss 0.16791, batch_time 1.143
# epoch 2, iter 174, loss 0.12241, batch_time 1.146
# epoch 2, iter 175, loss 0.13729, batch_time 1.158
# epoch 2, iter 176, loss 0.12849, batch_time 1.148
# epoch 2, iter 177, loss 0.11850, batch_time 1.133
# epoch 2, iter 178, loss 0.13081, batch_time 1.149
# epoch 2, iter 179, loss 0.12812, batch_time 1.136
# epoch 2, iter 180, loss 0.12427, batch_time 1.142
# epoch 2, iter 181, loss 0.13106, batch_time 1.144
# epoch 2, iter 182, loss 0.11053, batch_time 1.217
# epoch 2, iter 183, loss 0.13336, batch_time 1.245
# epoch 2, iter 184, loss 0.13398, batch_time 1.192
# epoch 2, iter 185, loss 0.11803, batch_time 1.145
# epoch 2, iter 186, loss 0.13850, batch_time 1.142
# epoch 2, iter 187, loss 0.14035, batch_time 1.123
# epoch 2, iter 188, loss 0.11823, batch_time 1.153
# epoch 2, iter 189, loss 0.13237, batch_time 1.164
# epoch 2, iter 190, loss 0.15793, batch_time 1.158
# epoch 2, iter 191, loss 0.15121, batch_time 1.151
# epoch 2, iter 192, loss 0.12404, batch_time 1.228
# epoch 2, iter 193, loss 0.11995, batch_time 1.257
# epoch 2, iter 194, loss 0.12882, batch_time 1.248
# epoch 2, iter 195, loss 0.12945, batch_time 1.236
# epoch 2, iter 196, loss 0.13365, batch_time 1.175
# epoch 2, iter 197, loss 0.12741, batch_time 1.242
# epoch 2, iter 198, loss 0.15785, batch_time 1.228
# epoch 2, iter 199, loss 0.12713, batch_time 1.241
# epoch 2, iter 200, loss 0.13078, batch_time 1.150
# epoch 2, iter 201, loss 0.11215, batch_time 1.160
# epoch 2, iter 202, loss 0.10721, batch_time 1.149
# epoch 2, iter 203, loss 0.15695, batch_time 1.144
# epoch 2, iter 204, loss 0.12223, batch_time 1.154
# epoch 2, iter 205, loss 0.10754, batch_time 1.144
# epoch 2, iter 206, loss 0.12753, batch_time 1.149
# epoch 2, iter 207, loss 0.14925, batch_time 1.145
# epoch 2, iter 208, loss 0.10247, batch_time 1.134
# epoch 2, iter 209, loss 0.11468, batch_time 1.152
# epoch 2, iter 210, loss 0.10285, batch_time 1.141
# epoch 2, iter 211, loss 0.11312, batch_time 1.170
# epoch 2, iter 212, loss 0.14536, batch_time 1.156
# epoch 2, iter 213, loss 0.15198, batch_time 1.147
# epoch 2, iter 214, loss 0.11183, batch_time 1.153
# epoch 2, iter 215, loss 0.13376, batch_time 1.164
# epoch 2, iter 216, loss 0.09901, batch_time 1.136
# epoch 2, iter 217, loss 0.13454, batch_time 1.133
# epoch 2, iter 218, loss 0.11952, batch_time 1.133
# epoch 2, iter 219, loss 0.10486, batch_time 1.167
# epoch 2, iter 220, loss 0.10856, batch_time 1.222
# epoch 2, iter 221, loss 0.11103, batch_time 1.219
# epoch 2, iter 222, loss 0.12808, batch_time 1.219
# epoch 2, iter 223, loss 0.13230, batch_time 1.205
# epoch 2, iter 224, loss 0.12924, batch_time 1.219
# epoch 2, iter 225, loss 0.12531, batch_time 1.207
# epoch 2, iter 226, loss 0.11827, batch_time 1.212
# epoch 2, iter 227, loss 0.10764, batch_time 1.213
# epoch 2, iter 228, loss 0.13154, batch_time 1.212
# epoch 2, iter 229, loss 0.13898, batch_time 1.169
# epoch 2, iter 230, loss 0.13056, batch_time 1.197
# epoch 2, iter 231, loss 0.12334, batch_time 1.152
# epoch 2, iter 232, loss 0.12973, batch_time 1.223
# epoch 2, iter 233, loss 0.16226, batch_time 1.156
# epoch 2, iter 234, loss 0.14015, batch_time 1.227
# epoch 2, iter 235, loss 0.12109, batch_time 1.173
# epoch 2, iter 236, loss 0.11311, batch_time 1.213
# epoch 2, iter 237, loss 0.12802, batch_time 1.208
# epoch 2, iter 238, loss 0.11340, batch_time 1.201
# epoch 2, iter 239, loss 0.11908, batch_time 1.197
# epoch 2, iter 240, loss 0.13236, batch_time 1.196
# epoch 2, iter 241, loss 0.12179, batch_time 1.197
# epoch 2, iter 242, loss 0.11368, batch_time 1.201
# epoch 2, iter 243, loss 0.13125, batch_time 1.211
# epoch 2, iter 244, loss 0.12444, batch_time 1.260
# epoch 2, iter 245, loss 0.09442, batch_time 1.173
# epoch 2, iter 246, loss 0.12661, batch_time 1.226
# epoch 2, iter 247, loss 0.11881, batch_time 1.158
# epoch 2, iter 248, loss 0.10840, batch_time 1.220
# epoch 2, iter 249, loss 0.14180, batch_time 1.183
# epoch 2, iter 250, loss 0.10729, batch_time 1.174
# epoch 2, iter 251, loss 0.13195, batch_time 1.145
# epoch 2, iter 252, loss 0.14772, batch_time 1.167
# epoch 2, iter 253, loss 0.11345, batch_time 1.164
# epoch 2, iter 254, loss 0.11762, batch_time 1.174
# epoch 2, iter 255, loss 0.12557, batch_time 1.142
# epoch 2, iter 256, loss 0.10640, batch_time 1.191
# epoch 2, iter 257, loss 0.10723, batch_time 1.146
# epoch 2, iter 258, loss 0.11784, batch_time 1.277
# epoch 2, iter 259, loss 0.12889, batch_time 1.222
# epoch 2, iter 260, loss 0.09321, batch_time 1.218
# epoch 2, iter 261, loss 0.11806, batch_time 1.209
# epoch 2, iter 262, loss 0.10965, batch_time 1.217
# epoch 2, iter 263, loss 0.12307, batch_time 1.211
# epoch 2, iter 264, loss 0.11049, batch_time 1.213
# epoch 2, iter 265, loss 0.10304, batch_time 1.147
# epoch 2, iter 266, loss 0.14631, batch_time 1.166
# epoch 2, iter 267, loss 0.11630, batch_time 1.153
# epoch 2, iter 268, loss 0.10974, batch_time 1.242
# epoch 2, iter 269, loss 0.11012, batch_time 1.167
# epoch 2, iter 270, loss 0.12496, batch_time 1.177
# epoch 2, iter 271, loss 0.11404, batch_time 1.177
# epoch 2, iter 272, loss 0.12375, batch_time 1.163
# epoch 2, iter 273, loss 0.11632, batch_time 1.176
# epoch 2, iter 274, loss 0.12662, batch_time 1.272
# epoch 2, iter 275, loss 0.11414, batch_time 1.163
# epoch 2, iter 276, loss 0.12569, batch_time 1.164
# epoch 2, iter 277, loss 0.10127, batch_time 1.258
# epoch 2, iter 278, loss 0.11550, batch_time 1.157
# epoch 2, iter 279, loss 0.11868, batch_time 1.237
# epoch 2, iter 280, loss 0.14074, batch_time 0.962
# Train Loss:  18.068723812699318
# Dev Loss:  2.4740867614746094
#
# epoch 3, iter 281, loss 0.10425, batch_time 1.164
# epoch 3, iter 282, loss 0.08558, batch_time 1.162
# epoch 3, iter 283, loss 0.07219, batch_time 1.233
# epoch 3, iter 284, loss 0.07143, batch_time 1.224
# epoch 3, iter 285, loss 0.07703, batch_time 1.200
# epoch 3, iter 286, loss 0.07872, batch_time 1.164
# epoch 3, iter 287, loss 0.06353, batch_time 1.163
# epoch 3, iter 288, loss 0.07545, batch_time 1.224
# epoch 3, iter 289, loss 0.08885, batch_time 1.192
# epoch 3, iter 290, loss 0.06594, batch_time 1.207
# epoch 3, iter 291, loss 0.07103, batch_time 1.248
# epoch 3, iter 292, loss 0.06641, batch_time 1.222
# epoch 3, iter 293, loss 0.09277, batch_time 1.176
# epoch 3, iter 294, loss 0.08013, batch_time 1.149
# epoch 3, iter 295, loss 0.07943, batch_time 1.164
# epoch 3, iter 296, loss 0.08003, batch_time 1.254
# epoch 3, iter 297, loss 0.07348, batch_time 1.148
# epoch 3, iter 298, loss 0.07342, batch_time 1.160
# epoch 3, iter 299, loss 0.09180, batch_time 1.140
# epoch 3, iter 300, loss 0.07535, batch_time 1.158
# epoch 3, iter 301, loss 0.08048, batch_time 1.213
# epoch 3, iter 302, loss 0.08205, batch_time 1.172
# epoch 3, iter 303, loss 0.06858, batch_time 1.175
# epoch 3, iter 304, loss 0.09990, batch_time 1.152
# epoch 3, iter 305, loss 0.08461, batch_time 1.152
# epoch 3, iter 306, loss 0.07324, batch_time 1.202
# epoch 3, iter 307, loss 0.08113, batch_time 1.170
# epoch 3, iter 308, loss 0.05223, batch_time 1.147
# epoch 3, iter 309, loss 0.07589, batch_time 1.178
# epoch 3, iter 310, loss 0.06712, batch_time 1.151
# epoch 3, iter 311, loss 0.06480, batch_time 1.143
# epoch 3, iter 312, loss 0.08727, batch_time 1.140
# epoch 3, iter 313, loss 0.06362, batch_time 1.160
# epoch 3, iter 314, loss 0.05205, batch_time 1.162
# epoch 3, iter 315, loss 0.06231, batch_time 1.154
# epoch 3, iter 316, loss 0.07336, batch_time 1.171
# epoch 3, iter 317, loss 0.06792, batch_time 1.157
# epoch 3, iter 318, loss 0.06763, batch_time 1.145
# epoch 3, iter 319, loss 0.07719, batch_time 1.167
# epoch 3, iter 320, loss 0.09721, batch_time 1.152
# epoch 3, iter 321, loss 0.06553, batch_time 1.225
# epoch 3, iter 322, loss 0.09322, batch_time 1.245
# epoch 3, iter 323, loss 0.06582, batch_time 1.171
# epoch 3, iter 324, loss 0.07824, batch_time 1.158
# epoch 3, iter 325, loss 0.06399, batch_time 1.148
# epoch 3, iter 326, loss 0.06928, batch_time 1.163
# epoch 3, iter 327, loss 0.07083, batch_time 1.156
# epoch 3, iter 328, loss 0.05966, batch_time 1.152
# epoch 3, iter 329, loss 0.06050, batch_time 1.163
# epoch 3, iter 330, loss 0.08882, batch_time 1.183
# epoch 3, iter 331, loss 0.07094, batch_time 1.279
# epoch 3, iter 332, loss 0.07992, batch_time 1.278
# epoch 3, iter 333, loss 0.06362, batch_time 1.178
# epoch 3, iter 334, loss 0.09334, batch_time 1.200
# epoch 3, iter 335, loss 0.10283, batch_time 1.254
# epoch 3, iter 336, loss 0.08398, batch_time 1.163
# epoch 3, iter 337, loss 0.07533, batch_time 1.159
# epoch 3, iter 338, loss 0.07066, batch_time 1.152
# epoch 3, iter 339, loss 0.07658, batch_time 1.153
# epoch 3, iter 340, loss 0.07173, batch_time 1.203
# epoch 3, iter 341, loss 0.06944, batch_time 1.144
# epoch 3, iter 342, loss 0.08691, batch_time 1.176
# epoch 3, iter 343, loss 0.06734, batch_time 1.219
# epoch 3, iter 344, loss 0.08833, batch_time 1.253
# epoch 3, iter 345, loss 0.07606, batch_time 1.159
# epoch 3, iter 346, loss 0.06661, batch_time 1.167
# epoch 3, iter 347, loss 0.08259, batch_time 1.156
# epoch 3, iter 348, loss 0.06489, batch_time 1.158
# epoch 3, iter 349, loss 0.06224, batch_time 1.169
# epoch 3, iter 350, loss 0.08721, batch_time 1.233
# epoch 3, iter 351, loss 0.06139, batch_time 1.235
# epoch 3, iter 352, loss 0.06431, batch_time 1.244
# epoch 3, iter 353, loss 0.07293, batch_time 1.232
# epoch 3, iter 354, loss 0.09009, batch_time 1.152
# epoch 3, iter 355, loss 0.09694, batch_time 1.184
# epoch 3, iter 356, loss 0.10222, batch_time 1.235
# epoch 3, iter 357, loss 0.06359, batch_time 1.229
# epoch 3, iter 358, loss 0.07491, batch_time 1.241
# epoch 3, iter 359, loss 0.06642, batch_time 1.147
# epoch 3, iter 360, loss 0.06320, batch_time 1.155
# epoch 3, iter 361, loss 0.06993, batch_time 1.163
# epoch 3, iter 362, loss 0.08921, batch_time 1.246
# epoch 3, iter 363, loss 0.06368, batch_time 1.223
# epoch 3, iter 364, loss 0.08338, batch_time 1.237
# epoch 3, iter 365, loss 0.07817, batch_time 1.180
# epoch 3, iter 366, loss 0.07870, batch_time 1.162
# epoch 3, iter 367, loss 0.09203, batch_time 1.158
# epoch 3, iter 368, loss 0.06006, batch_time 1.249
# epoch 3, iter 369, loss 0.08165, batch_time 1.239
# epoch 3, iter 370, loss 0.08321, batch_time 1.217
# epoch 3, iter 371, loss 0.07390, batch_time 1.205
# epoch 3, iter 372, loss 0.06158, batch_time 1.252
# epoch 3, iter 373, loss 0.07186, batch_time 1.170
# epoch 3, iter 374, loss 0.07424, batch_time 1.158
# epoch 3, iter 375, loss 0.08834, batch_time 1.170
# epoch 3, iter 376, loss 0.07802, batch_time 1.155
# epoch 3, iter 377, loss 0.06301, batch_time 1.255
# epoch 3, iter 378, loss 0.09590, batch_time 1.226
# epoch 3, iter 379, loss 0.08104, batch_time 1.185
# epoch 3, iter 380, loss 0.10711, batch_time 1.145
# epoch 3, iter 381, loss 0.08282, batch_time 1.180
# epoch 3, iter 382, loss 0.07595, batch_time 1.151
# epoch 3, iter 383, loss 0.10181, batch_time 1.141
# epoch 3, iter 384, loss 0.08723, batch_time 1.168
# epoch 3, iter 385, loss 0.07929, batch_time 1.141
# epoch 3, iter 386, loss 0.08093, batch_time 1.233
# epoch 3, iter 387, loss 0.07392, batch_time 1.253
# epoch 3, iter 388, loss 0.08162, batch_time 1.208
# epoch 3, iter 389, loss 0.07847, batch_time 1.162
# epoch 3, iter 390, loss 0.05181, batch_time 1.153
# epoch 3, iter 391, loss 0.08789, batch_time 1.163
# epoch 3, iter 392, loss 0.09411, batch_time 1.171
# epoch 3, iter 393, loss 0.08439, batch_time 1.247
# epoch 3, iter 394, loss 0.09835, batch_time 1.152
# epoch 3, iter 395, loss 0.08755, batch_time 1.160
# epoch 3, iter 396, loss 0.06792, batch_time 1.194
# epoch 3, iter 397, loss 0.05504, batch_time 1.159
# epoch 3, iter 398, loss 0.08533, batch_time 1.147
# epoch 3, iter 399, loss 0.07785, batch_time 1.227
# epoch 3, iter 400, loss 0.07877, batch_time 1.158
# epoch 3, iter 401, loss 0.07120, batch_time 1.147
# epoch 3, iter 402, loss 0.07224, batch_time 1.232
# epoch 3, iter 403, loss 0.08461, batch_time 1.134
# epoch 3, iter 404, loss 0.08987, batch_time 1.225
# epoch 3, iter 405, loss 0.08248, batch_time 1.165
# epoch 3, iter 406, loss 0.07457, batch_time 1.160
# epoch 3, iter 407, loss 0.08615, batch_time 1.241
# epoch 3, iter 408, loss 0.08355, batch_time 1.168
# epoch 3, iter 409, loss 0.08808, batch_time 1.157
# epoch 3, iter 410, loss 0.06547, batch_time 1.219
# epoch 3, iter 411, loss 0.07260, batch_time 1.208
# epoch 3, iter 412, loss 0.08165, batch_time 1.148
# epoch 3, iter 413, loss 0.07724, batch_time 1.157
# epoch 3, iter 414, loss 0.08252, batch_time 1.171
# epoch 3, iter 415, loss 0.07126, batch_time 1.168
# epoch 3, iter 416, loss 0.07073, batch_time 1.222
# epoch 3, iter 417, loss 0.05872, batch_time 1.223
# epoch 3, iter 418, loss 0.08643, batch_time 1.197
# epoch 3, iter 419, loss 0.09549, batch_time 1.245
# epoch 3, iter 420, loss 0.08931, batch_time 0.966
# Train Loss:  10.828059196472168
# Dev Loss:  3.0204928815364838

# %%
preds = deep_ce_self1.predict(X_rnn['dev'])

# %%
evaluate(Y_rnn_binary_dev, preds)
# Out:
# p, r, f1: 0.6331, 0.7711, 0.6953
#
# average F1 score: 0.695335
